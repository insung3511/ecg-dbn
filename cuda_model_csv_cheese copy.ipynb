# %% [markdown]
# # Init set up

# %%
from ignite.contrib.metrics.regression import *
from ignite.contrib.metrics import *
from ignite.handlers import *
from ignite.metrics import *
from ignite.engine import *
from ignite.utils import *

from torch.utils.data import DataLoader
from torch.autograd import Variable
import torch.nn.functional as F
import data.read_samples as rs
import torch.optim as optim
import torch.utils.data
import torch.nn as nn

from collections import OrderedDict
import pandas as pd
import numpy as np
import datetime
import torch
import time
import os
import gc

print(datetime.datetime.now(), "model.py code start")

TRAIN_CSV_PATH = "./data/mitbih_train.csv"
TEST_CSV_PATH = "./data/mitbih_test.csv"

BATCH_SIZE = 10
EPOCH = 100
LEARNING_RATE = 0.2
ANNEALING_RATE = 0.999
VISIBLE_UNITS = [180, 200, 250]
HIDDEN_UNITS = [80, 100, 120]
K_FOLD = 1
# Out:
# [INFO] Pre-processing for make clean
# 2022-05-18 17:04:20.912459 model.py code start

# %%
device = torch.device('cuda')
print(torch.cuda.get_device_name(device))
os.environ['KMP_DUPLICATE_LIB_OK']='True'
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
# Out:
# NVIDIA GeForce RTX 3080 Laptop GPU

# %%
class RBM(nn.Module): 
    with torch.cuda.device(0):
        def __init__(self, n_vis, n_hid, k, batch):
            super(RBM, self).__init__()
            self.W      = nn.Parameter(torch.randn(1, batch, device=device) * 1e-2)
            self.n_vis  = n_vis
            self.n_hid  = n_hid
            self.k      = k
            self.batch  = batch
            self.v_bias = nn.Parameter(torch.zeros(n_vis, device=device))
            self.h_bias = nn.Parameter(torch.zeros(n_hid, device=device))
        
        def sample_from_p(self, p):
            return F.relu(
                torch.sign(
                    p - Variable(torch.randn(p.size(), device=device))
                )
            ).to(device=device)

        ''' ISSUE PART '''
        def v_to_h(self, v):
            w = (self.W.clone())

            p_h = F.sigmoid(
                F.linear(v, w)
            ).to(device=device)

            sample_h = self.sample_from_p(p_h)
            return p_h, sample_h

        def h_to_v(self, h):
            w = self.W.t().clone()

            p_v = F.sigmoid(
                F.linear(h, w)
            ).to(device=device)

            sample_v = self.sample_from_p(p_v)
            return p_v, sample_v
        
        def forward(self, v):
            pre_h1, h1 = self.v_to_h(v)
            h_ = h1

            for _ in range(self.k):
                pre_v_, v_ = self.h_to_v(h_)
                pre_h_, h_ = self.v_to_h(v_)
            return v, v_
        
        def get_weight(self):
            return self.W

# %%
class SVM(nn.Module):
    def __init__(self, lr, n_x):
        super(SVM, self).__init__()
        self.lr = lr
        self.fully = nn.Linear(n_x, 1)
    
    def forward(self, x):
        fwd = self.fully(x)
        return fwd

# %%
def eval_step(engine, batch):
    return batch

default_model = nn.Sequential(OrderedDict([
    ('base', nn.Linear(4, 2)),
    ('fc', nn.Linear(2, 1))
]))

default_evaluator = Engine(eval_step)

def get_acc(y_true, y_pred):
    metric = Accuracy()
    metric.attach(default_evaluator, "accuracy")
    state = default_evaluator.run([[y_pred, y_true]])
    return state.metrics["accuracy"]

# %% [markdown]
# # Pre-processing

# %%
print("[MODL] Model main code is starting....")
print("[INFO] Read train data, cross-vaildation data and test data from median filtering code")

train_df = pd.read_csv(TRAIN_CSV_PATH, header=None).sample(frac=1)
test_df = pd.read_csv(TEST_CSV_PATH, header=None)

Y = np.array(train_df[187].values).astype(np.int8)
X = np.array(train_df[list(range(187))].values)[..., np.newaxis]

Y_test = np.array(test_df[187].values).astype(np.int8)
X_test = np.array(test_df[list(range(187))].values)[..., np.newaxis]

print(len(X), len(Y), len(X_test), len(Y_test))
print(type(X), type(Y), type(X_test), type(Y_test))
# Out:
# [MODL] Model main code is starting....
# [INFO] Read train data, cross-vaildation data and test data from median filtering code
# 87554 87554 21892 21892
# <class 'numpy.ndarray'> <class 'numpy.ndarray'> <class 'numpy.ndarray'> <class 'numpy.ndarray'>

# %%
train_dataloader = DataLoader(X,
                              batch_size=BATCH_SIZE,
                              num_workers=0,
                              shuffle=True)

test_dataloader = DataLoader(Y,
                             batch_size=BATCH_SIZE,
                             num_workers=0,
                             shuffle=True)

# %% [markdown]
# ## Setting Models

# %%
rbm_first = RBM(n_vis=VISIBLE_UNITS[0], n_hid=HIDDEN_UNITS[0], k=K_FOLD, batch=BATCH_SIZE).to(device=device)
rbm_second = RBM(n_vis=VISIBLE_UNITS[1], n_hid=HIDDEN_UNITS[1], k=K_FOLD, batch=BATCH_SIZE).to(device=device)
rbm_third = RBM(n_vis=VISIBLE_UNITS[2], n_hid=HIDDEN_UNITS[2], k=K_FOLD, batch=BATCH_SIZE).to(device=device)

first_train_op = optim.Adagrad(rbm_first.parameters(), LEARNING_RATE)
second_train_op = optim.Adagrad(rbm_second.parameters(), LEARNING_RATE)
third_train_op = optim.Adagrad(rbm_third.parameters(), LEARNING_RATE)

gb_first_train_op = optim.Adagrad(rbm_first.parameters(), LEARNING_RATE)
gb_second_train_op = optim.Adagrad(rbm_second.parameters(), LEARNING_RATE)
gb_third_train_op = optim.Adagrad(rbm_third.parameters(), LEARNING_RATE)

omse_loss = list()
output_bb = list()
output_gb = list()
best_acc = 0.
mse_loss = nn.MSELoss()

gaussian_std = torch.arange(1, 0, -0.1, device=device)

svm_model = SVM(lr=LEARNING_RATE, n_x=10)
svm_optimizer = optim.Adagrad(svm_model.parameters(), lr=LEARNING_RATE)

# %% [markdown]
# # GB-DBN Train Code

# %%
'''BBRBM Train Part'''

loss_ = []
print("RBM START!")

for epoch in range(EPOCH):
    tmp_acc = float()
    run_acc = float()
    start = time.time()
    '''First bbrbm'''
    for i, (data) in enumerate(train_dataloader):
        data = Variable(torch.tensor(data, dtype=torch.float32))
        if(data.size()[0] == 4):
            break
        
        sample_data = torch.bernoulli(data).view(-1, 10).to(device=device)
        fs_data = sample_data
        # tensor binary
        fvog_first, v1 = rbm_first(sample_data)
        omse_loss = mse_loss(fvog_first, v1)
        
        first_train_op.zero_grad()
        first_train_op.step()
        omse_loss.backward()
    
    for _, (data) in enumerate(v1): 
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)

        sample_data = torch.bernoulli(data).view(-1, 10).to(device=device)

        # tensor binary
        vog_second, v2 = rbm_second(sample_data)
        omse_loss = mse_loss(vog_second, v2)

        second_train_op.zero_grad()
        omse_loss.backward()
        second_train_op.step()
    
    for _, (data) in enumerate(v2):
        start = time.time()
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)

        sample_data = torch.bernoulli(data).view(-1, 10).to(device=device)

        vog_third, v3 = rbm_third(sample_data)
        omse_loss = mse_loss(vog_third, v3)
        
        third_train_op.zero_grad()
        omse_loss.backward()
        third_train_op.step()

        run_acc += (sample_data == v3).sum().item()
    output_bb.append(v3)

    '''
GBRBM GBRBM GBRBM GBRBM GBRBM GBRBM GBRBM 
    '''

    for i, (data) in enumerate(output_bb):
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)
        
        sample_data = torch.normal(mean=data, std=gaussian_std).view(-1, 10).to(device=device)

        # tensor binary
        vog_first, v1 = rbm_first(sample_data)
        omse_loss = mse_loss(vog_first, v1)

        first_train_op.zero_grad()
        first_train_op.step()
        omse_loss.backward()

    for _, (data) in enumerate(v1): 
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)

        sample_data = torch.normal(mean=data, std=gaussian_std).view(-1, 10).to(device=device)

        # tensor binary
        vog_second, v2 = rbm_second(sample_data)
        omse_loss = mse_loss(vog_second, v2)

        second_train_op.zero_grad()
        omse_loss.backward()
        second_train_op.step()

    for _, (data) in enumerate(v2):
        start = time.time()
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)

        sample_data = torch.normal(mean=data, std=gaussian_std).view(-1, 10).to(device=device)

        vog_third, v3_e = rbm_third(sample_data)
        omse_loss = mse_loss(vog_third, v3_e)
        
        third_train_op.zero_grad()
        omse_loss.backward()
        third_train_op.step()

        # output_gb.append(torch.flatten(v3_e).tolist())
        run_acc += (torch.bernoulli(data).view(-1, 10).to(device=device) == v3_e).sum().item()  
    
    acc_v = (vog_third >= 0).float()
    acc = get_acc(
        acc_v, v3_e
    ) * 100
    
    if acc >= best_acc:
        best_acc = acc    
        path = "./saveMode_through_" + str(epoch) + "_epoch_" + str(best_acc) + "_acc_GBDBN.pth"
        torch.save(rbm_third.state_dict(), path)

    print("GB-DBN Training loss for {0}th epoch {1}\tEstimate time : {2}\tAcc : {3}\tBest Acc : {4}\t\tIgnite Acc: {5}" \
        .format(epoch + 1, omse_loss, time.time() - start, acc, best_acc, tmp_acc))
    gc.collect()
# Out:
# RBM START!
# C:\Users\HILAB_~1\AppData\Local\Temp/ipykernel_24920/974587165.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data = Variable(torch.tensor(data, dtype=torch.float32))
# c:\Users\HILAB_Labtop_02\anaconda3\lib\site-packages\torch\nn\functional.py:1944: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# C:\Users\HILAB_~1\AppData\Local\Temp/ipykernel_24920/974587165.py:28: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(data, dtype=torch.float32)
# C:\Users\HILAB_~1\AppData\Local\Temp/ipykernel_24920/974587165.py:44: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(data, dtype=torch.float32)
# C:\Users\HILAB_~1\AppData\Local\Temp/ipykernel_24920/974587165.py:65: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(data, dtype=torch.float32)
# C:\Users\HILAB_~1\AppData\Local\Temp/ipykernel_24920/974587165.py:80: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(data, dtype=torch.float32)
# C:\Users\HILAB_~1\AppData\Local\Temp/ipykernel_24920/974587165.py:96: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(data, dtype=torch.float32)
# GB-DBN Training loss for 1th epoch 0.5110470056533813	Estimate time : 0.0069997310638427734	Acc : 60.0	Best Acc : 60.0		Ignite Acc: 0.0
# GB-DBN Training loss for 2th epoch 0.5478244423866272	Estimate time : 0.005995512008666992	Acc : 50.0	Best Acc : 60.0		Ignite Acc: 0.0
# GB-DBN Training loss for 3th epoch 0.29882335662841797	Estimate time : 0.006995677947998047	Acc : 60.0	Best Acc : 60.0		Ignite Acc: 0.0
# GB-DBN Training loss for 4th epoch 1.0770107507705688	Estimate time : 0.0060002803802490234	Acc : 50.0	Best Acc : 60.0		Ignite Acc: 0.0
# GB-DBN Training loss for 5th epoch 0.29728102684020996	Estimate time : 0.00801539421081543	Acc : 70.0	Best Acc : 70.0		Ignite Acc: 0.0
# GB-DBN Training loss for 6th epoch 0.8902849555015564	Estimate time : 0.00800013542175293	Acc : 40.0	Best Acc : 70.0		Ignite Acc: 0.0
# GB-DBN Training loss for 7th epoch 0.6456780433654785	Estimate time : 0.009000301361083984	Acc : 60.0	Best Acc : 70.0		Ignite Acc: 0.0
# GB-DBN Training loss for 8th epoch 0.5952502489089966	Estimate time : 0.010005712509155273	Acc : 70.0	Best Acc : 70.0		Ignite Acc: 0.0
# GB-DBN Training loss for 9th epoch 0.49912601709365845	Estimate time : 0.010003805160522461	Acc : 60.0	Best Acc : 70.0		Ignite Acc: 0.0
# GB-DBN Training loss for 10th epoch 0.5238696932792664	Estimate time : 0.012000322341918945	Acc : 80.0	Best Acc : 80.0		Ignite Acc: 0.0
# GB-DBN Training loss for 11th epoch 0.5209294557571411	Estimate time : 0.01199960708618164	Acc : 90.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 12th epoch 0.7047180533409119	Estimate time : 0.026996135711669922	Acc : 60.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 13th epoch 0.47671738266944885	Estimate time : 0.02900075912475586	Acc : 40.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 14th epoch 0.32916259765625	Estimate time : 0.014000177383422852	Acc : 60.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 15th epoch 0.22552771866321564	Estimate time : 0.015996456146240234	Acc : 90.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 16th epoch 0.7260796427726746	Estimate time : 0.03099989891052246	Acc : 70.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 17th epoch 0.9515900015830994	Estimate time : 0.016000032424926758	Acc : 60.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 18th epoch 1.0640558004379272	Estimate time : 0.01799798011779785	Acc : 50.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 19th epoch 0.8834360241889954	Estimate time : 0.016995668411254883	Acc : 20.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 20th epoch 0.657626211643219	Estimate time : 0.018000364303588867	Acc : 60.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 21th epoch 0.9805676341056824	Estimate time : 0.01899576187133789	Acc : 50.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 22th epoch 0.9733087420463562	Estimate time : 0.04099750518798828	Acc : 50.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 23th epoch 0.41509637236595154	Estimate time : 0.020000457763671875	Acc : 40.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 24th epoch 0.6495851874351501	Estimate time : 0.04399895668029785	Acc : 60.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 25th epoch 0.5801679491996765	Estimate time : 0.04304671287536621	Acc : 80.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 26th epoch 1.4499772787094116	Estimate time : 0.022994041442871094	Acc : 60.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 27th epoch 0.6158236265182495	Estimate time : 0.050997018814086914	Acc : 70.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 28th epoch 0.48941221833229065	Estimate time : 0.02199554443359375	Acc : 70.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 29th epoch 0.34238219261169434	Estimate time : 0.050997257232666016	Acc : 90.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 30th epoch 0.5921853184700012	Estimate time : 0.014995574951171875	Acc : 60.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 31th epoch 0.4751426875591278	Estimate time : 0.02699565887451172	Acc : 90.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 32th epoch 0.42416998744010925	Estimate time : 0.026999950408935547	Acc : 60.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 33th epoch 0.7061753869056702	Estimate time : 0.02699732780456543	Acc : 50.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 34th epoch 0.36156049370765686	Estimate time : 0.028000593185424805	Acc : 60.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 35th epoch 0.9573782086372375	Estimate time : 0.030005455017089844	Acc : 50.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 36th epoch 0.61918044090271	Estimate time : 0.06097674369812012	Acc : 60.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 37th epoch 0.828438937664032	Estimate time : 0.030996084213256836	Acc : 50.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 38th epoch 0.9039368629455566	Estimate time : 0.06262683868408203	Acc : 50.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 39th epoch 0.7723556756973267	Estimate time : 0.0709996223449707	Acc : 50.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 40th epoch 0.18721918761730194	Estimate time : 0.03200054168701172	Acc : 50.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 41th epoch 0.27097252011299133	Estimate time : 0.03274106979370117	Acc : 50.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 42th epoch 0.40086373686790466	Estimate time : 0.03299546241760254	Acc : 60.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 43th epoch 0.5380957722663879	Estimate time : 0.03399515151977539	Acc : 80.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 44th epoch 0.6027805209159851	Estimate time : 0.03699970245361328	Acc : 50.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 45th epoch 1.0095608234405518	Estimate time : 0.035997629165649414	Acc : 80.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 46th epoch 0.3571241796016693	Estimate time : 0.03600001335144043	Acc : 70.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 47th epoch 0.46670007705688477	Estimate time : 0.03699994087219238	Acc : 70.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 48th epoch 1.2587308883666992	Estimate time : 0.03799557685852051	Acc : 60.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 49th epoch 0.495652973651886	Estimate time : 0.040000200271606445	Acc : 60.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 50th epoch 0.7459700703620911	Estimate time : 0.040000200271606445	Acc : 60.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 51th epoch 0.5534667372703552	Estimate time : 0.04199981689453125	Acc : 50.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 52th epoch 0.5839580297470093	Estimate time : 0.040997982025146484	Acc : 70.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 53th epoch 0.6347367167472839	Estimate time : 0.040997982025146484	Acc : 60.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 54th epoch 1.307386875152588	Estimate time : 0.04200005531311035	Acc : 20.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 55th epoch 0.549444854259491	Estimate time : 0.041998863220214844	Acc : 80.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 56th epoch 0.8466987013816833	Estimate time : 0.0970001220703125	Acc : 40.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 57th epoch 0.6404731273651123	Estimate time : 0.08199572563171387	Acc : 70.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 58th epoch 0.8293914198875427	Estimate time : 0.043999433517456055	Acc : 40.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 59th epoch 0.5167571902275085	Estimate time : 0.04399991035461426	Acc : 60.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 60th epoch 0.6448278427124023	Estimate time : 0.04599595069885254	Acc : 50.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 61th epoch 1.4455453157424927	Estimate time : 0.04699563980102539	Acc : 50.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 62th epoch 0.351873517036438	Estimate time : 0.09400033950805664	Acc : 60.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 63th epoch 0.6419225931167603	Estimate time : 0.04800009727478027	Acc : 80.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 64th epoch 0.6839020848274231	Estimate time : 0.054000139236450195	Acc : 40.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 65th epoch 0.7774117588996887	Estimate time : 0.05200004577636719	Acc : 70.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 66th epoch 1.7893304824829102	Estimate time : 0.051000118255615234	Acc : 50.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 67th epoch 0.7703129649162292	Estimate time : 0.051000356674194336	Acc : 70.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 68th epoch 0.4293290078639984	Estimate time : 0.05500006675720215	Acc : 80.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 69th epoch 0.47238394618034363	Estimate time : 0.05200028419494629	Acc : 60.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 70th epoch 0.6870665550231934	Estimate time : 0.05499982833862305	Acc : 30.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 71th epoch 0.6663522124290466	Estimate time : 0.1100001335144043	Acc : 70.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 72th epoch 0.6381472945213318	Estimate time : 0.11100006103515625	Acc : 60.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 73th epoch 0.523798406124115	Estimate time : 0.06000852584838867	Acc : 70.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 74th epoch 0.6368301510810852	Estimate time : 0.056005239486694336	Acc : 40.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 75th epoch 0.6903429627418518	Estimate time : 0.11600446701049805	Acc : 80.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 76th epoch 1.0323435068130493	Estimate time : 0.054000139236450195	Acc : 30.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 77th epoch 1.1713184118270874	Estimate time : 0.06102919578552246	Acc : 50.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 78th epoch 0.9135624766349792	Estimate time : 0.1289968490600586	Acc : 30.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 79th epoch 0.6817212104797363	Estimate time : 0.0579986572265625	Acc : 50.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 80th epoch 0.6336446404457092	Estimate time : 0.05999898910522461	Acc : 40.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 81th epoch 0.6464083790779114	Estimate time : 0.06500816345214844	Acc : 70.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 82th epoch 0.9888233542442322	Estimate time : 0.12799763679504395	Acc : 60.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 83th epoch 1.0879913568496704	Estimate time : 0.12399983406066895	Acc : 40.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 84th epoch 1.0844697952270508	Estimate time : 0.07200217247009277	Acc : 50.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 85th epoch 0.42973271012306213	Estimate time : 0.13098907470703125	Acc : 90.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 86th epoch 0.44468003511428833	Estimate time : 0.14000248908996582	Acc : 70.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 87th epoch 0.7404495477676392	Estimate time : 0.06899881362915039	Acc : 60.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 88th epoch 1.0595035552978516	Estimate time : 0.06899666786193848	Acc : 40.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 89th epoch 0.6562377214431763	Estimate time : 0.08299994468688965	Acc : 50.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 90th epoch 0.16939400136470795	Estimate time : 0.06899523735046387	Acc : 80.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 91th epoch 0.5206525921821594	Estimate time : 0.06999993324279785	Acc : 70.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 92th epoch 0.8894932866096497	Estimate time : 0.07099580764770508	Acc : 40.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 93th epoch 0.8455286026000977	Estimate time : 0.06999993324279785	Acc : 50.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 94th epoch 0.44072648882865906	Estimate time : 0.09199976921081543	Acc : 80.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 95th epoch 1.240186095237732	Estimate time : 0.1550004482269287	Acc : 50.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 96th epoch 0.8492760062217712	Estimate time : 0.15358209609985352	Acc : 70.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 97th epoch 1.035922884941101	Estimate time : 0.05599570274353027	Acc : 40.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 98th epoch 0.5983585715293884	Estimate time : 0.07299637794494629	Acc : 70.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 99th epoch 0.9627098441123962	Estimate time : 0.07399535179138184	Acc : 40.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 100th epoch 0.554478108882904	Estimate time : 0.07700085639953613	Acc : 90.0	Best Acc : 90.0		Ignite Acc: 0.0

# %%
# load_model = RBM(VISIBLE_UNITS[2], VISIBLE_UNITS[2], K_FOLD, BATCH_SIZE)
# load_model.load_state_dict(torch.load("./saveMode_through_99_epoch_90.0_acc_GBDBN.pth"))

LOAD_PATH = "./saveMode_through_99_epoch_90.0_acc_GBDBN.pth"

load_model = RBM(VISIBLE_UNITS[2], HIDDEN_UNITS[2], K_FOLD, BATCH_SIZE)
load_model.load_state_dict((torch.load(LOAD_PATH)))
load_model.eval()
print(load_model)
# Out:
# <bound method RBM.forward of RBM()>

# %%
print("Last Accuracy : ", acc, "%")
# Out:
# Last Accuracy :  90.0 %

# %%
cpu = torch.device('cpu')

# %%
db3_label_chan = list()
v_model_acc = list()

for i in range(len(Y)):
    temp_list = []
    temp_bool = []
    for j in range(2577):
        try:
            temp_str = db3_label[i][j]
        except IndexError:
            temp_str = ""

        if temp_str == "V":
            temp_list.append(0)
            temp_bool.append(True)

        else:
            temp_list.append(1)
            temp_bool.append(False)

    db3_label_chan.append(temp_list)
    v_model_acc.append(temp_bool)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\HILAB_~1\AppData\Local\Temp/ipykernel_24920/750903716.py in <module>
#       7     for j in range(2577):
#       8         try:
# ----> 9             temp_str = db3_label[i][j]
#      10         except IndexError:
#      11             temp_str = ""
#
# NameError: name 'db3_label' is not defined

# %%
correct = 0.
cnt_tot = 0

for epoch in range(EPOCH):
    perm = torch.randperm(N)
    for  i in range(0, N, BATCH_SIZE):
        x = svm_X[perm[i:i + BATCH_SIZE]]
        y = svm_Y[perm[i:i + BATCH_SIZE]]

        x = torch.tensor(x.clone().detach())
        y = torch.tensor(y.clone().detach())

        # Forward
        output = model(x)
        
        # Backward
        optimizer.zero_grad()        
        optimizer.step()

        predicted = output.data >= 0
        correct += float(
            predicted.view(-1) == output.data
        )

        cnt_tot += 1
    print("Epoch: {}\tLoss: {}\tTotal Cnt: {}".format(epoch, correct, cnt_tot))
    torch.save(model, "Train_svm_model.pth")

# %% [markdown]
# # Test Code

# %%
run_acc = float()
best_acc = float()
print("Test Code GB-DBN Start")
for i, (data) in enumerate(test_dataloader):
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)
        
        sample_data = torch.bernoulli(data).view(-1, 10).to(device=device)

        # tensor binary
        vog_first, v1 = rbm_first(sample_data)
        omse_loss = mse_loss(vog_first, v1)

        first_train_op.zero_grad()
        first_train_op.step()
        omse_loss.backward()

for i, (data) in enumerate(v1):
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)
        
        sample_data = torch.bernoulli(data).view(-1, 10).to(device=device)

        # tensor binary
        vog_second, v2 = rbm_first(sample_data)
        omse_loss = mse_loss(vog_second, v2)

        second_train_op.zero_grad()
        second_train_op.step()
        omse_loss.backward()

for i, (data) in enumerate(v2):
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)
        
        sample_data = torch.bernoulli(data).view(-1, 10).to(device=device)

        # tensor binary
        vog_second, v3 = rbm_first(sample_data)
        omse_loss = mse_loss(vog_second, v3)

        second_train_op.zero_grad()
        second_train_op.step()
        omse_loss.backward()
        run_acc += (sample_data == v3).sum().item()
 
for _, (data) in enumerate(v3): 
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)

        sample_data = torch.normal(mean=data, std=gaussian_std).view(-1, 10).to(device=device)

        # tensor binary
        vog_second, v1 = rbm_first(sample_data)
        omse_loss = mse_loss(vog_second, v1)

        second_train_op.zero_grad()
        omse_loss.backward()
        second_train_op.step()

for _, (data) in enumerate(v1): 
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)

        sample_data = torch.normal(mean=data, std=gaussian_std).view(-1, 10).to(device=device)

        # tensor binary
        vog_second, v2 = rbm_second(sample_data)
        omse_loss = mse_loss(vog_second, v2)

        second_train_op.zero_grad()
        omse_loss.backward()
        second_train_op.step()
        
for _, (data) in enumerate(v2): 
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)

        sample_data = torch.normal(mean=data, std=gaussian_std).view(-1, 10).to(device=device)

        # tensor binary
        vog_second, v3 = rbm_third(sample_data)
        omse_loss = mse_loss(vog_second, v3)

        second_train_op.zero_grad()
        omse_loss.backward()
        second_train_op.step()

print("GB-DBN Training loss: {0}\tEstimate time : {1}\tAcc : {2}" .format(omse_loss, time.time() - start, acc * 100))

# %%
svm_v = torch.tensor(v3.clone().detach(), device=torch.device('cpu'))
print(svm_v)

# %%
X = torch.FloatTensor(svm_v)
Y = torch.FloatTensor(svm_v)
N = len(Y)

model = SVM(lr=LEARNING_RATE, n_x=10)
optimizer = optim.Adagrad(model.parameters(), lr=LEARNING_RATE)

correct = 0.
cnt_tot = 0

x = torch.tensor(X)
y = torch.tensor(Y)

# Forward
output = model(x)

# Backward
optimizer.zero_grad()
optimizer.step()

# %%
print(output)
