# %% [markdown]
# # Init set up

# %%
from ignite.contrib.metrics.regression import *
from ignite.contrib.metrics import *
from ignite.handlers import *
from ignite.metrics import *
from ignite.engine import *
from ignite.utils import *

from torch.utils.data import DataLoader
from torch.autograd import Variable
import torch.nn.functional as F
import data.read_samples as rs
import torch.optim as optim
import torch.utils.data
import torch.nn as nn

from collections import OrderedDict
import pandas as pd
import numpy as np
import datetime
import torch
import time
import os
import gc

print(datetime.datetime.now(), "model.py code start")

TRAIN_CSV_PATH = "./data/mitbih_train.csv"
TEST_CSV_PATH = "./data/mitbih_test.csv"

BATCH_SIZE = 187
EPOCH = 200
LEARNING_RATE = 0.2
ANNEALING_RATE = 0.999
HIDDEN_UNITS = [180, 200, 250, 80, 100, 120]
K_FOLD = 1
# Out:
# [INFO] Pre-processing for make clean
# 2022-05-19 09:59:09.105682 model.py code start

# %%
device = torch.device('cuda')
print(torch.cuda.get_device_name(device))
os.environ['KMP_DUPLICATE_LIB_OK']='True'
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
# Out:
# NVIDIA GeForce RTX 3080 Laptop GPU

# %%
class RBM(nn.Module): 
    with torch.cuda.device(0):
        def __init__(self, n_vis, n_hid, k, batch):
            super(RBM, self).__init__()
            self.W      = nn.Parameter(torch.randn(1, batch, device=device) * 1e-2)
            self.n_vis  = n_vis
            self.n_hid  = n_hid
            self.k      = k
            self.batch  = batch
            self.v_bias = nn.Parameter(torch.zeros(n_vis, 1, device=device))
            self.h_bias = nn.Parameter(torch.zeros(n_hid, 1, device=device))
        
        def sample_from_p(self, p):
            return F.relu(
                torch.sign(
                    p - Variable(torch.randn(p.size(), device=device))
                )
            ).to(device=device)

        ''' ISSUE PART '''
        def v_to_h(self, v):
            w = (self.W.clone())

            p_h = F.sigmoid(
                F.linear(v, w)
            ).to(device=device)

            sample_h = self.sample_from_p(p_h)
            return p_h, sample_h

        def h_to_v(self, h):
            w = self.W.t().clone()

            p_v = F.sigmoid(
                F.linear(h, w)
            ).to(device=device)

            sample_v = self.sample_from_p(p_v)
            return p_v, sample_v
        
        def forward(self, v):
            pre_h1, h1 = self.v_to_h(v)
            h_ = h1

            for _ in range(self.k):
                pre_v_, v_ = self.h_to_v(h_)
                pre_h_, h_ = self.v_to_h(v_)
            return v, v_
        
        def get_weight(self):
            return self.W

# %%
class SVM(nn.Module):
    def __init__(self, lr, n_x):
        super(SVM, self).__init__()
        self.lr = lr
        self.fully = nn.Linear(n_x, 1)
    
    def forward(self, x):
        fwd = self.fully(x)
        return fwd

# %%
def eval_step(engine, batch):
    return batch

default_model = nn.Sequential(OrderedDict([
    ('base', nn.Linear(4, 2)),
    ('fc', nn.Linear(2, 1))
]))

default_evaluator = Engine(eval_step)

def get_acc(y_true, y_pred):
    metric = Accuracy()
    metric.attach(default_evaluator, "accuracy")
    state = default_evaluator.run([[y_pred, y_true]])
    return state.metrics["accuracy"]

# %% [markdown]
# # Pre-processing

# %%
print("[MODL] Model main code is starting....")
print("[INFO] Read train data, cross-vaildation data and test data from median filtering code")

train_df = pd.read_csv(TRAIN_CSV_PATH, header=None).sample(frac=1)
test_df = pd.read_csv(TEST_CSV_PATH, header=None)

Y = np.array(train_df[187].values).astype(np.int8)
X = np.array(train_df[list(range(187))].values)[..., np.newaxis]

Y_test = np.array(test_df[187].values).astype(np.int8)
X_test = np.array(test_df[list(range(187))].values)[..., np.newaxis]

print(len(X), len(Y), len(X_test), len(Y_test))
print(type(X), type(Y), type(X_test), type(Y_test))
# Out:
# [MODL] Model main code is starting....
# [INFO] Read train data, cross-vaildation data and test data from median filtering code
# 87554 87554 21892 21892
# <class 'numpy.ndarray'> <class 'numpy.ndarray'> <class 'numpy.ndarray'> <class 'numpy.ndarray'>

# %%
train_dataset = []
cross_dataset = []
test_dataset = []

train_dataloader = DataLoader(X,
                              batch_size=BATCH_SIZE,
                              num_workers=0,
                              shuffle=True)

test_dataloader = DataLoader(Y,
                             batch_size=BATCH_SIZE,
                             num_workers=0,
                             shuffle=True)

# %% [markdown]
# ## Setting Models

# %%
bbrbm_first = RBM(n_vis=187, n_hid=HIDDEN_UNITS[0], k=K_FOLD, batch=BATCH_SIZE).to(device=device)
bbrbm_second = RBM(n_vis=187, n_hid=HIDDEN_UNITS[1], k=K_FOLD, batch=BATCH_SIZE).to(device=device)
bbrbm_third = RBM(n_vis=187, n_hid=HIDDEN_UNITS[2], k=K_FOLD, batch=BATCH_SIZE).to(device=device)

gbrbm_first = RBM(n_vis=187, n_hid=HIDDEN_UNITS[3], k=K_FOLD, batch=BATCH_SIZE).to(device=device)
gbrbm_second = RBM(n_vis=187, n_hid=HIDDEN_UNITS[4], k=K_FOLD, batch=BATCH_SIZE).to(device=device)
gbrbm_third = RBM(n_vis=187, n_hid=HIDDEN_UNITS[5], k=K_FOLD, batch=BATCH_SIZE).to(device=device)

first_train_op = optim.Adagrad(bbrbm_first.parameters(), LEARNING_RATE)
second_train_op = optim.Adagrad(bbrbm_second.parameters(), LEARNING_RATE)
third_train_op = optim.Adagrad(bbrbm_third.parameters(), LEARNING_RATE)

gb_first_train_op = optim.Adagrad(gbrbm_first.parameters(), LEARNING_RATE)
gb_second_train_op = optim.Adagrad(gbrbm_second.parameters(), LEARNING_RATE)
gb_third_train_op = optim.Adagrad(gbrbm_third.parameters(), LEARNING_RATE)

omse_loss = list()
output_gb = list()
best_acc = float()
mse_loss = nn.MSELoss()

gaussian_std = torch.arange(1, 0, -0.00537, device=device)
print(gaussian_std.size())

svm_X = torch.FloatTensor(output_gb)
svm_Y = torch.FloatTensor(Y)
N = len(svm_Y)

svm_model = SVM(lr=LEARNING_RATE, n_x=2577)
svm_optimizer = optim.Adagrad(svm_model.parameters(), lr=LEARNING_RATE)
# Out:
# torch.Size([187])

# %%
# # load_model = RBM(VISIBLE_UNITS[2], VISIBLE_UNITS[2], K_FOLD, BATCH_SIZE)
# # load_model.load_state_dict(torch.load("./saveMode_through_99_epoch_90.0_acc_GBDBN.pth"))

# LOAD_PATH = "./saveMode_through_99_epoch_90.0_acc_GBDBN.pth"

# load_model = RBM(VISIBLE_UNITS[2], HIDDEN_UNITS[2], K_FOLD, 10)
# load_model.load_state_dict((torch.load(LOAD_PATH)))
# load_model.to(device=device)

# for i, (data) in enumerate(test_dataloader):
#         if(data.size()[0] == 4):
#             break
#         data = Variable(
#                 torch.tensor(data, dtype=torch.float32)
#         ).uniform_(0, 1)
        
#         sample_data = torch.bernoulli(data).view(-1, 10).to(device=device)

#         # tensor binary
#         vog_first, v1 = load_model(sample_data)
#         omse_loss = mse_loss(vog_first, v1)

#         first_train_op.zero_grad()
#         first_train_op.step()
#         omse_loss.backward()
# get_acc(vog_first, v1)

# %% [markdown]
# # GB-DBN Train Code

# %%
'''BBRBM Train Part'''

loss_ = []
output_bb = []
print("RBM START!")

for epoch in range(EPOCH):
    tmp_acc = float()
    run_acc = float()
    start = time.time()
    '''First bbrbm'''
    for i, (data) in enumerate(train_dataloader):
        data = Variable(torch.tensor(data, dtype=torch.float32))
        if(data.size()[0] == 4):
            break
        
        sample_data = torch.bernoulli(data).view(-1, BATCH_SIZE).to(device=device)
        fs_data = sample_data
        
        # tensor binary
        fvog_first, v1 = bbrbm_first(sample_data)
        omse_loss = mse_loss(fvog_first, v1)
        
        first_train_op.zero_grad()
        first_train_op.step()
        omse_loss.backward()
    
    for _, (data) in enumerate(v1): 
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)

        sample_data = torch.bernoulli(data).view(-1, BATCH_SIZE).to(device=device)

        # tensor binary
        vog_second, v2 = bbrbm_second(sample_data)
        omse_loss = mse_loss(vog_second, v2)

        second_train_op.zero_grad()
        omse_loss.backward()
        second_train_op.step()
    
    for _, (data) in enumerate(v2):
        start = time.time()
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)

        sample_data = torch.bernoulli(data).view(-1, BATCH_SIZE).to(device=device)

        vog_third, v3 = bbrbm_third(sample_data)
        omse_loss = mse_loss(vog_third, v3)
        
        third_train_op.zero_grad()
        omse_loss.backward()
        third_train_op.step()

        run_acc += (sample_data == v3).sum().item()
    
    path = "./saveMode_through_BBRBM.pth"
    torch.save(bbrbm_second.state_dict(), path)
    output_bb.append(v3)

    '''
        GBRBM GBRBM GBRBM GBRBM GBRBM GBRBM GBRBM 
    '''

    for i, (data) in enumerate(output_bb):
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)
        
        sample_data = torch.normal(mean=data, std=gaussian_std).view(-1, BATCH_SIZE).to(device=device)

        # tensor binary
        vog_first, v1 = gbrbm_first(sample_data)
        omse_loss = mse_loss(vog_first, v1)

        gb_first_train_op.zero_grad()
        gb_first_train_op.step()
        omse_loss.backward()

    for _, (data) in enumerate(v1): 
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)

        sample_data = torch.normal(mean=data, std=gaussian_std).view(-1, BATCH_SIZE).to(device=device)

        # tensor binary
        vog_second, v2 = gbrbm_second(sample_data)
        omse_loss = mse_loss(vog_second, v2)

        gb_second_train_op.zero_grad()
        omse_loss.backward()
        gb_second_train_op.step()

    for _, (data) in enumerate(v2):
        start = time.time()
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)

        sample_data = torch.normal(mean=data, std=gaussian_std).view(-1, BATCH_SIZE).to(device=device)

        vog_third, v3_e = gbrbm_third(sample_data)
        omse_loss = mse_loss(vog_third, v3_e)
        
        gb_third_train_op.zero_grad()
        omse_loss.backward()
        gb_third_train_op.step()
    
    # perm = torch.randperm(N)
    # for i in range(0, N, BATCH_SIZE):
    #     correct = 0.

    #     x = svm_X[perm[i:i + BATCH_SIZE]]
    #     y = svm_Y[perm[i:i + BATCH_SIZE]]

    #     x = torch.tensor(x.clone().detach())
    #     y = torch.tensor(y.clone().detach())

    #     # Forward
    #     output = svm_model(x)
        
    #     # Backward
    #     svm_optimizer.zero_grad()        
    #     svm_optimizer.step()

    #     predicted = output.data >= 0
    #     correct += float(
    #         predicted.view(-1) == output.data
    #     )
    # torch.save(svm_model, "Train_svm_model.pth")
    
    acc_v = (vog_third >= 0).float()
    acc = get_acc(
        acc_v, v3_e
    ) * 100
    
    if acc > best_acc:
        best_acc = acc    
        path = "./say_cheese/ahh_saveMode_through_" + str(epoch) + "_" + str(acc) + "GBRBM.pth"
        torch.save(gbrbm_third.state_dict(), path)
    output_gb.append(v3_e)

    print("GB-DBN Training loss for {0}th epoch {1}\tEstimate time : {2}\tAcc : {3}\t\tBest Acc : {4}\t\tIgnite Acc: {5}" \
        .format(epoch + 1, omse_loss, time.time() - start, acc, best_acc, tmp_acc))
    gc.collect()
# Out:
# RBM START!
# C:\Users\HILAB_~1\AppData\Local\Temp/ipykernel_22724/2533437238.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data = Variable(torch.tensor(data, dtype=torch.float32))
# c:\Users\HILAB_Labtop_02\anaconda3\lib\site-packages\torch\nn\functional.py:1944: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# C:\Users\HILAB_~1\AppData\Local\Temp/ipykernel_22724/2533437238.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(data, dtype=torch.float32)
# C:\Users\HILAB_~1\AppData\Local\Temp/ipykernel_22724/2533437238.py:46: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(data, dtype=torch.float32)
# C:\Users\HILAB_~1\AppData\Local\Temp/ipykernel_22724/2533437238.py:70: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(data, dtype=torch.float32)
# C:\Users\HILAB_~1\AppData\Local\Temp/ipykernel_22724/2533437238.py:85: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(data, dtype=torch.float32)
# C:\Users\HILAB_~1\AppData\Local\Temp/ipykernel_22724/2533437238.py:101: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(data, dtype=torch.float32)
# GB-DBN Training loss for 1th epoch 0.7403568625450134	Estimate time : 0.007999658584594727	Acc : 58.82352941176471		Best Acc : 58.82352941176471		Ignite Acc: 0.0
# GB-DBN Training loss for 2th epoch 0.7468371391296387	Estimate time : 0.005000114440917969	Acc : 57.21925133689839		Best Acc : 58.82352941176471		Ignite Acc: 0.0
# GB-DBN Training loss for 3th epoch 0.8219496011734009	Estimate time : 0.009999752044677734	Acc : 59.893048128342244		Best Acc : 59.893048128342244		Ignite Acc: 0.0
# GB-DBN Training loss for 4th epoch 0.6264271140098572	Estimate time : 0.01300048828125	Acc : 63.101604278074866		Best Acc : 63.101604278074866		Ignite Acc: 0.0
# GB-DBN Training loss for 5th epoch 0.7576298713684082	Estimate time : 0.009001493453979492	Acc : 61.49732620320856		Best Acc : 63.101604278074866		Ignite Acc: 0.0
# GB-DBN Training loss for 6th epoch 0.7000561356544495	Estimate time : 0.01199960708618164	Acc : 58.82352941176471		Best Acc : 63.101604278074866		Ignite Acc: 0.0
# GB-DBN Training loss for 7th epoch 0.7101705074310303	Estimate time : 0.009999752044677734	Acc : 61.49732620320856		Best Acc : 63.101604278074866		Ignite Acc: 0.0
# GB-DBN Training loss for 8th epoch 0.6655314564704895	Estimate time : 0.010995149612426758	Acc : 60.42780748663101		Best Acc : 63.101604278074866		Ignite Acc: 0.0
# GB-DBN Training loss for 9th epoch 0.6087354421615601	Estimate time : 0.01700115203857422	Acc : 65.24064171122996		Best Acc : 65.24064171122996		Ignite Acc: 0.0
# GB-DBN Training loss for 10th epoch 0.5343272089958191	Estimate time : 0.019001483917236328	Acc : 69.5187165775401		Best Acc : 69.5187165775401		Ignite Acc: 0.0
# GB-DBN Training loss for 11th epoch 0.5693634152412415	Estimate time : 0.01375889778137207	Acc : 62.56684491978609		Best Acc : 69.5187165775401		Ignite Acc: 0.0
# GB-DBN Training loss for 12th epoch 0.6009181141853333	Estimate time : 0.013000965118408203	Acc : 60.962566844919785		Best Acc : 69.5187165775401		Ignite Acc: 0.0
# GB-DBN Training loss for 13th epoch 0.6917992234230042	Estimate time : 0.014999151229858398	Acc : 56.14973262032086		Best Acc : 69.5187165775401		Ignite Acc: 0.0
# GB-DBN Training loss for 14th epoch 0.8570783734321594	Estimate time : 0.014999628067016602	Acc : 58.288770053475936		Best Acc : 69.5187165775401		Ignite Acc: 0.0
# GB-DBN Training loss for 15th epoch 0.627871572971344	Estimate time : 0.015604734420776367	Acc : 62.03208556149733		Best Acc : 69.5187165775401		Ignite Acc: 0.0
# GB-DBN Training loss for 16th epoch 0.5029898285865784	Estimate time : 0.01599884033203125	Acc : 65.24064171122996		Best Acc : 69.5187165775401		Ignite Acc: 0.0
# GB-DBN Training loss for 17th epoch 0.7591351866722107	Estimate time : 0.017999887466430664	Acc : 53.475935828877006		Best Acc : 69.5187165775401		Ignite Acc: 0.0
# GB-DBN Training loss for 18th epoch 0.6507629752159119	Estimate time : 0.01899886131286621	Acc : 65.77540106951871		Best Acc : 69.5187165775401		Ignite Acc: 0.0
# GB-DBN Training loss for 19th epoch 0.6986851096153259	Estimate time : 0.016998291015625	Acc : 61.49732620320856		Best Acc : 69.5187165775401		Ignite Acc: 0.0
# GB-DBN Training loss for 20th epoch 0.7787430882453918	Estimate time : 0.02199864387512207	Acc : 57.75401069518716		Best Acc : 69.5187165775401		Ignite Acc: 0.0
# GB-DBN Training loss for 21th epoch 0.789242684841156	Estimate time : 0.019999980926513672	Acc : 57.75401069518716		Best Acc : 69.5187165775401		Ignite Acc: 0.0
# GB-DBN Training loss for 22th epoch 0.7931619882583618	Estimate time : 0.019999265670776367	Acc : 56.68449197860963		Best Acc : 69.5187165775401		Ignite Acc: 0.0
# GB-DBN Training loss for 23th epoch 0.7204065918922424	Estimate time : 0.021998882293701172	Acc : 60.42780748663101		Best Acc : 69.5187165775401		Ignite Acc: 0.0
# GB-DBN Training loss for 24th epoch 0.8178831338882446	Estimate time : 0.023998498916625977	Acc : 56.68449197860963		Best Acc : 69.5187165775401		Ignite Acc: 0.0
# GB-DBN Training loss for 25th epoch 0.6456345319747925	Estimate time : 0.02299952507019043	Acc : 61.49732620320856		Best Acc : 69.5187165775401		Ignite Acc: 0.0
# GB-DBN Training loss for 26th epoch 0.7484004497528076	Estimate time : 0.021999120712280273	Acc : 59.35828877005348		Best Acc : 69.5187165775401		Ignite Acc: 0.0
# GB-DBN Training loss for 27th epoch 0.8079632520675659	Estimate time : 0.023999691009521484	Acc : 60.962566844919785		Best Acc : 69.5187165775401		Ignite Acc: 0.0
# GB-DBN Training loss for 28th epoch 0.6590397357940674	Estimate time : 0.02399897575378418	Acc : 65.77540106951871		Best Acc : 69.5187165775401		Ignite Acc: 0.0
# GB-DBN Training loss for 29th epoch 0.6153377890586853	Estimate time : 0.028595924377441406	Acc : 70.58823529411765		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 30th epoch 0.6350083947181702	Estimate time : 0.02899909019470215	Acc : 62.03208556149733		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 31th epoch 0.6675865054130554	Estimate time : 0.02899932861328125	Acc : 64.1711229946524		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 32th epoch 0.6822253465652466	Estimate time : 0.029998779296875	Acc : 60.42780748663101		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 33th epoch 0.7552611827850342	Estimate time : 0.03199958801269531	Acc : 57.75401069518716		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 34th epoch 0.5576481819152832	Estimate time : 0.030998945236206055	Acc : 62.56684491978609		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 35th epoch 0.5541765689849854	Estimate time : 0.03199911117553711	Acc : 64.70588235294117		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 36th epoch 0.6813468933105469	Estimate time : 0.03099989891052246	Acc : 66.31016042780749		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 37th epoch 0.6835872530937195	Estimate time : 0.03199934959411621	Acc : 55.080213903743314		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 38th epoch 0.7264602184295654	Estimate time : 0.03600335121154785	Acc : 56.68449197860963		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 39th epoch 0.6549657583236694	Estimate time : 0.035007476806640625	Acc : 58.82352941176471		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 40th epoch 0.6207528710365295	Estimate time : 0.037000179290771484	Acc : 65.77540106951871		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 41th epoch 0.6062500476837158	Estimate time : 0.03499889373779297	Acc : 62.03208556149733		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 42th epoch 0.611918032169342	Estimate time : 0.03599977493286133	Acc : 63.63636363636363		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 43th epoch 0.6574616432189941	Estimate time : 0.03799891471862793	Acc : 57.21925133689839		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 44th epoch 0.7313550114631653	Estimate time : 0.03799915313720703	Acc : 58.82352941176471		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 45th epoch 0.6353955864906311	Estimate time : 0.03799891471862793	Acc : 59.35828877005348		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 46th epoch 0.6399210691452026	Estimate time : 0.03900003433227539	Acc : 63.101604278074866		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 47th epoch 0.7107178568840027	Estimate time : 0.040997982025146484	Acc : 58.82352941176471		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 48th epoch 0.5221648216247559	Estimate time : 0.047997474670410156	Acc : 67.37967914438502		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 49th epoch 0.6838645935058594	Estimate time : 0.040999650955200195	Acc : 51.33689839572193		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 50th epoch 0.4830443263053894	Estimate time : 0.042000532150268555	Acc : 66.84491978609626		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 51th epoch 0.6986030340194702	Estimate time : 0.043999433517456055	Acc : 59.893048128342244		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 52th epoch 0.6573446989059448	Estimate time : 0.04300069808959961	Acc : 60.42780748663101		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 53th epoch 0.6197457313537598	Estimate time : 0.04500436782836914	Acc : 68.44919786096256		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 54th epoch 0.7193057537078857	Estimate time : 0.04500007629394531	Acc : 59.893048128342244		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 55th epoch 0.682435154914856	Estimate time : 0.04599928855895996	Acc : 59.35828877005348		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 56th epoch 0.5732027888298035	Estimate time : 0.04600048065185547	Acc : 61.49732620320856		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 57th epoch 0.5933418273925781	Estimate time : 0.04700112342834473	Acc : 64.1711229946524		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 58th epoch 0.7856917381286621	Estimate time : 0.05000019073486328	Acc : 60.962566844919785		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 59th epoch 0.7816015481948853	Estimate time : 0.04799962043762207	Acc : 63.63636363636363		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 60th epoch 0.7346425652503967	Estimate time : 0.04999542236328125	Acc : 61.49732620320856		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 61th epoch 0.7059912085533142	Estimate time : 0.050605058670043945	Acc : 60.42780748663101		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 62th epoch 0.6177021861076355	Estimate time : 0.049996376037597656	Acc : 62.56684491978609		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 63th epoch 0.6388047933578491	Estimate time : 0.05299544334411621	Acc : 65.77540106951871		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 64th epoch 0.7590749263763428	Estimate time : 0.05299544334411621	Acc : 63.101604278074866		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 65th epoch 0.6564449667930603	Estimate time : 0.052999258041381836	Acc : 61.49732620320856		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 66th epoch 0.6293804049491882	Estimate time : 0.055014848709106445	Acc : 64.70588235294117		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 67th epoch 0.7481614351272583	Estimate time : 0.05499887466430664	Acc : 64.1711229946524		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 68th epoch 0.7342451214790344	Estimate time : 0.05599474906921387	Acc : 62.03208556149733		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 69th epoch 0.7483998537063599	Estimate time : 0.05699920654296875	Acc : 63.101604278074866		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 70th epoch 0.586185872554779	Estimate time : 0.05700039863586426	Acc : 59.893048128342244		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 71th epoch 0.6403363943099976	Estimate time : 0.05800032615661621	Acc : 63.63636363636363		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 72th epoch 0.6558468341827393	Estimate time : 0.0579991340637207	Acc : 56.68449197860963		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 73th epoch 0.6441264748573303	Estimate time : 0.05799436569213867	Acc : 58.82352941176471		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 74th epoch 0.757341206073761	Estimate time : 0.06000041961669922	Acc : 65.24064171122996		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 75th epoch 0.7661221027374268	Estimate time : 0.06300497055053711	Acc : 60.962566844919785		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 76th epoch 0.6683719754219055	Estimate time : 0.06099748611450195	Acc : 61.49732620320856		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 77th epoch 0.7660170793533325	Estimate time : 0.060999393463134766	Acc : 58.82352941176471		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 78th epoch 0.7028043270111084	Estimate time : 0.06199908256530762	Acc : 63.63636363636363		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 79th epoch 0.7132256627082825	Estimate time : 0.06200051307678223	Acc : 59.35828877005348		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 80th epoch 0.6526657342910767	Estimate time : 0.06299948692321777	Acc : 65.77540106951871		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 81th epoch 0.7417557239532471	Estimate time : 0.07700037956237793	Acc : 60.42780748663101		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 82th epoch 0.704460620880127	Estimate time : 0.07000064849853516	Acc : 58.82352941176471		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 83th epoch 0.6114978194236755	Estimate time : 0.0639955997467041	Acc : 66.84491978609626		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 84th epoch 0.8575553297996521	Estimate time : 0.06600093841552734	Acc : 58.288770053475936		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 85th epoch 0.6504491567611694	Estimate time : 0.069000244140625	Acc : 59.893048128342244		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 86th epoch 0.636911928653717	Estimate time : 0.06799912452697754	Acc : 58.82352941176471		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 87th epoch 0.7363532781600952	Estimate time : 0.06999874114990234	Acc : 64.70588235294117		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 88th epoch 0.7469089031219482	Estimate time : 0.06799650192260742	Acc : 60.42780748663101		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 89th epoch 0.6009063720703125	Estimate time : 0.06905269622802734	Acc : 64.70588235294117		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 90th epoch 0.6856493949890137	Estimate time : 0.07100033760070801	Acc : 60.42780748663101		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 91th epoch 0.7301350235939026	Estimate time : 0.06998610496520996	Acc : 59.35828877005348		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 92th epoch 0.6895952820777893	Estimate time : 0.07099270820617676	Acc : 65.24064171122996		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 93th epoch 0.683742105960846	Estimate time : 0.07399439811706543	Acc : 58.82352941176471		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 94th epoch 0.7001795172691345	Estimate time : 0.0749964714050293	Acc : 64.1711229946524		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 95th epoch 0.728206217288971	Estimate time : 0.07399892807006836	Acc : 57.21925133689839		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 96th epoch 0.6742698550224304	Estimate time : 0.07399749755859375	Acc : 59.35828877005348		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 97th epoch 0.6753954887390137	Estimate time : 0.07599997520446777	Acc : 63.101604278074866		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 98th epoch 0.6723939776420593	Estimate time : 0.07500004768371582	Acc : 64.70588235294117		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 99th epoch 0.7016172409057617	Estimate time : 0.0780038833618164	Acc : 65.24064171122996		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 100th epoch 0.6592479944229126	Estimate time : 0.07700085639953613	Acc : 66.84491978609626		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 101th epoch 0.6566634774208069	Estimate time : 0.07999944686889648	Acc : 60.962566844919785		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 102th epoch 0.5972955226898193	Estimate time : 0.0800008773803711	Acc : 68.98395721925134		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 103th epoch 0.6486984491348267	Estimate time : 0.08100008964538574	Acc : 63.101604278074866		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 104th epoch 0.6225773096084595	Estimate time : 0.0820004940032959	Acc : 58.82352941176471		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 105th epoch 0.666572630405426	Estimate time : 0.08199906349182129	Acc : 64.70588235294117		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 106th epoch 0.6684143543243408	Estimate time : 0.08385968208312988	Acc : 58.288770053475936		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 107th epoch 0.5502558350563049	Estimate time : 0.08299994468688965	Acc : 68.98395721925134		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 108th epoch 0.7028874754905701	Estimate time : 0.08299922943115234	Acc : 57.75401069518716		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 109th epoch 0.6239932775497437	Estimate time : 0.08461475372314453	Acc : 58.288770053475936		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 110th epoch 0.5326800346374512	Estimate time : 0.08699941635131836	Acc : 60.962566844919785		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 111th epoch 0.6255674362182617	Estimate time : 0.08499908447265625	Acc : 59.35828877005348		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 112th epoch 0.627785861492157	Estimate time : 0.0859994888305664	Acc : 58.82352941176471		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 113th epoch 0.5528221726417542	Estimate time : 0.08600187301635742	Acc : 62.56684491978609		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 114th epoch 0.6747750639915466	Estimate time : 0.08699584007263184	Acc : 55.080213903743314		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 115th epoch 0.6696781516075134	Estimate time : 0.08899593353271484	Acc : 64.70588235294117		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 116th epoch 0.686915934085846	Estimate time : 0.08899593353271484	Acc : 62.56684491978609		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 117th epoch 0.7444738149642944	Estimate time : 0.09499931335449219	Acc : 65.77540106951871		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 118th epoch 0.7028089165687561	Estimate time : 0.09099578857421875	Acc : 58.288770053475936		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 119th epoch 0.6717148423194885	Estimate time : 0.09200000762939453	Acc : 64.1711229946524		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 120th epoch 0.6480743885040283	Estimate time : 0.09199690818786621	Acc : 64.70588235294117		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 121th epoch 0.7438188195228577	Estimate time : 0.09099650382995605	Acc : 61.49732620320856		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 122th epoch 0.6782358288764954	Estimate time : 0.09605622291564941	Acc : 61.49732620320856		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 123th epoch 0.639412522315979	Estimate time : 0.09400010108947754	Acc : 60.962566844919785		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 124th epoch 0.6990554928779602	Estimate time : 0.09400033950805664	Acc : 62.56684491978609		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 125th epoch 0.6478393077850342	Estimate time : 0.09500002861022949	Acc : 62.03208556149733		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 126th epoch 0.5840719938278198	Estimate time : 0.09500002861022949	Acc : 59.893048128342244		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 127th epoch 0.7276753187179565	Estimate time : 0.09700465202331543	Acc : 64.70588235294117		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 128th epoch 0.8129681348800659	Estimate time : 0.09599995613098145	Acc : 63.101604278074866		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 129th epoch 0.6982178688049316	Estimate time : 0.09800028800964355	Acc : 60.42780748663101		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 130th epoch 0.5292031168937683	Estimate time : 0.10100030899047852	Acc : 61.49732620320856		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 131th epoch 0.68726646900177	Estimate time : 0.10000014305114746	Acc : 64.70588235294117		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 132th epoch 0.6602651476860046	Estimate time : 0.10000491142272949	Acc : 58.288770053475936		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 133th epoch 0.6744552850723267	Estimate time : 0.10100007057189941	Acc : 59.893048128342244		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 134th epoch 0.6650946140289307	Estimate time : 0.10900068283081055	Acc : 62.03208556149733		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 135th epoch 0.5327458381652832	Estimate time : 0.10299897193908691	Acc : 70.05347593582889		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 136th epoch 0.6241222620010376	Estimate time : 0.10500574111938477	Acc : 65.77540106951871		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 137th epoch 0.7348556518554688	Estimate time : 0.10699915885925293	Acc : 58.288770053475936		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 138th epoch 0.5247904062271118	Estimate time : 0.1069953441619873	Acc : 67.37967914438502		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 139th epoch 0.7207552194595337	Estimate time : 0.10499978065490723	Acc : 56.14973262032086		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 140th epoch 0.7224074602127075	Estimate time : 0.1060035228729248	Acc : 58.82352941176471		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 141th epoch 0.7966492176055908	Estimate time : 0.1060035228729248	Acc : 55.61497326203209		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 142th epoch 0.6425708532333374	Estimate time : 0.10899877548217773	Acc : 64.70588235294117		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 143th epoch 0.655307412147522	Estimate time : 0.11225724220275879	Acc : 62.03208556149733		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 144th epoch 0.605787992477417	Estimate time : 0.10799932479858398	Acc : 65.24064171122996		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 145th epoch 0.6246354579925537	Estimate time : 0.10999917984008789	Acc : 64.1711229946524		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 146th epoch 0.656757652759552	Estimate time : 0.11199951171875	Acc : 60.962566844919785		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 147th epoch 0.7293227910995483	Estimate time : 0.11100220680236816	Acc : 58.288770053475936		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 148th epoch 0.5680025815963745	Estimate time : 0.11099910736083984	Acc : 60.962566844919785		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 149th epoch 0.8432030081748962	Estimate time : 0.12328386306762695	Acc : 58.82352941176471		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 150th epoch 0.5645622611045837	Estimate time : 0.1140131950378418	Acc : 63.101604278074866		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 151th epoch 0.752478301525116	Estimate time : 0.11400365829467773	Acc : 55.080213903743314		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 152th epoch 0.9599093794822693	Estimate time : 0.11500310897827148	Acc : 59.893048128342244		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 153th epoch 0.6382638812065125	Estimate time : 0.11701107025146484	Acc : 64.70588235294117		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 154th epoch 0.5848677158355713	Estimate time : 0.1170036792755127	Acc : 69.5187165775401		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 155th epoch 0.6210428476333618	Estimate time : 0.11800312995910645	Acc : 68.98395721925134		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 156th epoch 0.6619865894317627	Estimate time : 0.11761331558227539	Acc : 62.03208556149733		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 157th epoch 0.7252309918403625	Estimate time : 0.11700320243835449	Acc : 59.893048128342244		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 158th epoch 0.6205835342407227	Estimate time : 0.12099933624267578	Acc : 66.84491978609626		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 159th epoch 0.5750616788864136	Estimate time : 0.12399959564208984	Acc : 57.21925133689839		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 160th epoch 0.4720565974712372	Estimate time : 0.11899971961975098	Acc : 65.77540106951871		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 161th epoch 0.7355855107307434	Estimate time : 0.12199950218200684	Acc : 66.31016042780749		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 162th epoch 0.5782155394554138	Estimate time : 0.1230003833770752	Acc : 62.56684491978609		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 163th epoch 0.6975059509277344	Estimate time : 0.12900257110595703	Acc : 59.893048128342244		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 164th epoch 0.5563562512397766	Estimate time : 0.12600445747375488	Acc : 59.893048128342244		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 165th epoch 0.6806063652038574	Estimate time : 0.12400507926940918	Acc : 64.70588235294117		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 166th epoch 0.702879011631012	Estimate time : 0.1270003318786621	Acc : 56.68449197860963		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 167th epoch 0.7442171573638916	Estimate time : 0.12500357627868652	Acc : 54.54545454545454		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 168th epoch 0.5608182549476624	Estimate time : 0.12699675559997559	Acc : 59.35828877005348		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 169th epoch 0.5623323321342468	Estimate time : 0.1269998550415039	Acc : 63.101604278074866		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 170th epoch 0.6776544451713562	Estimate time : 0.12799763679504395	Acc : 58.288770053475936		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 171th epoch 0.8185362815856934	Estimate time : 0.12900090217590332	Acc : 59.893048128342244		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 172th epoch 0.6222480535507202	Estimate time : 0.13000035285949707	Acc : 65.24064171122996		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 173th epoch 0.6708709001541138	Estimate time : 0.1300044059753418	Acc : 58.288770053475936		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 174th epoch 0.7267594933509827	Estimate time : 0.12999582290649414	Acc : 62.56684491978609		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 175th epoch 0.6367546916007996	Estimate time : 0.12899994850158691	Acc : 64.1711229946524		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 176th epoch 0.4930192232131958	Estimate time : 0.13300418853759766	Acc : 62.03208556149733		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 177th epoch 0.5614022016525269	Estimate time : 0.13300514221191406	Acc : 68.98395721925134		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 178th epoch 0.584114134311676	Estimate time : 0.13200163841247559	Acc : 58.82352941176471		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 179th epoch 0.7085810303688049	Estimate time : 0.13699555397033691	Acc : 59.35828877005348		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 180th epoch 0.6924028396606445	Estimate time : 0.14500069618225098	Acc : 54.01069518716578		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 181th epoch 0.7192932963371277	Estimate time : 0.13499689102172852	Acc : 65.77540106951871		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 182th epoch 0.6890192031860352	Estimate time : 0.13500404357910156	Acc : 60.42780748663101		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 183th epoch 0.6585550904273987	Estimate time : 0.13599610328674316	Acc : 60.962566844919785		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 184th epoch 0.5582862496376038	Estimate time : 0.13700318336486816	Acc : 62.03208556149733		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 185th epoch 0.668769896030426	Estimate time : 0.1379988193511963	Acc : 64.70588235294117		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 186th epoch 0.7045828104019165	Estimate time : 0.13899993896484375	Acc : 62.56684491978609		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 187th epoch 0.7946106195449829	Estimate time : 0.1399993896484375	Acc : 69.5187165775401		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 188th epoch 0.668519139289856	Estimate time : 0.14000415802001953	Acc : 58.288770053475936		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 189th epoch 0.5669095516204834	Estimate time : 0.143996000289917	Acc : 63.63636363636363		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 190th epoch 0.5722317099571228	Estimate time : 0.14100384712219238	Acc : 66.31016042780749		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 191th epoch 0.7550835609436035	Estimate time : 0.14326190948486328	Acc : 57.75401069518716		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 192th epoch 0.7184089422225952	Estimate time : 0.1430041790008545	Acc : 63.101604278074866		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 193th epoch 0.6600036025047302	Estimate time : 0.14399933815002441	Acc : 60.962566844919785		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 194th epoch 0.6740321516990662	Estimate time : 0.14499568939208984	Acc : 57.75401069518716		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 195th epoch 0.8117688894271851	Estimate time : 0.1459944248199463	Acc : 64.1711229946524		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 196th epoch 0.696542501449585	Estimate time : 0.14799785614013672	Acc : 59.35828877005348		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 197th epoch 0.6945879459381104	Estimate time : 0.1479952335357666	Acc : 63.63636363636363		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 198th epoch 0.739875853061676	Estimate time : 0.14885902404785156	Acc : 55.61497326203209		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 199th epoch 0.7553365230560303	Estimate time : 0.14800024032592773	Acc : 64.70588235294117		Best Acc : 70.58823529411765		Ignite Acc: 0.0
# GB-DBN Training loss for 200th epoch 0.5773099064826965	Estimate time : 0.15300369262695312	Acc : 66.84491978609626		Best Acc : 70.58823529411765		Ignite Acc: 0.0

# %%
print("Last Accuracy : ", acc, "%")
# Out:
# Last Accuracy :  66.84491978609626 %

# %%
# load_model = RBM(VISIBLE_UNITS[2], VISIBLE_UNITS[2], K_FOLD, BATCH_SIZE)
# load_model.load_state_dict(torch.load("./saveMode_through_99_epoch_90.0_acc_GBDBN.pth"))

LOAD_PATH = "./say_cheese/ahh_saveMode_through_83_71.12299465240642GBRBM.pth"

load_model = RBM(VISIBLE_UNITS[2], HIDDEN_UNITS[2], K_FOLD, BATCH_SIZE)
load_model.load_state_dict((torch.load(LOAD_PATH)))
load_model.to(device=device)

print(len(test_dataloader))

for i, (data) in enumerate(test_dataloader):
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)
        
        sample_data = torch.bernoulli(data).to(device=device)

        # tensor binary
        vog_first, v1 = load_model(sample_data)
        omse_loss = mse_loss(vog_first, v1)

        first_train_op.zero_grad()
        first_train_op.step()
        omse_loss.backward()
get_acc(vog_first, v1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\HILAB_~1\AppData\Local\Temp/ipykernel_22724/3177485033.py in <module>
#       4 LOAD_PATH = "./say_cheese/ahh_saveMode_through_83_71.12299465240642GBRBM.pth"
#       5
# ----> 6 load_model = RBM(VISIBLE_UNITS[2], HIDDEN_UNITS[2], K_FOLD, BATCH_SIZE)
#       7 load_model.load_state_dict((torch.load(LOAD_PATH)))
#       8 load_model.to(device=device)
#
# NameError: name 'VISIBLE_UNITS' is not defined

# %%
output_gb_cp = list()
cpu = torch.device('cpu')

# %% [markdown]
# # Test Code

# %%
run_acc = float()
best_acc = float()
print("Test Code GB-DBN Start")
for i, (data) in enumerate(test_dataloader):
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)
        
        sample_data = torch.bernoulli(data).view(-1, 10).to(device=device)

        # tensor binary
        vog_first, v1 = rbm_first(sample_data)
        omse_loss = mse_loss(vog_first, v1)

        first_train_op.zero_grad()
        first_train_op.step()
        omse_loss.backward()

for i, (data) in enumerate(v1):
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)
        
        sample_data = torch.bernoulli(data).view(-1, 10).to(device=device)

        # tensor binary
        vog_second, v2 = rbm_first(sample_data)
        omse_loss = mse_loss(vog_second, v2)

        second_train_op.zero_grad()
        second_train_op.step()
        omse_loss.backward()

for i, (data) in enumerate(v2):
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)
        
        sample_data = torch.bernoulli(data).view(-1, 10).to(device=device)

        # tensor binary
        vog_second, v3 = rbm_first(sample_data)
        omse_loss = mse_loss(vog_second, v3)

        second_train_op.zero_grad()
        second_train_op.step()
        omse_loss.backward()
        run_acc += (sample_data == v3).sum().item()
 
for _, (data) in enumerate(v3): 
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)

        sample_data = torch.normal(mean=data, std=gaussian_std).view(-1, 10).to(device=device)

        # tensor binary
        vog_second, v1 = rbm_first(sample_data)
        omse_loss = mse_loss(vog_second, v1)

        second_train_op.zero_grad()
        omse_loss.backward()
        second_train_op.step()

for _, (data) in enumerate(v1): 
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)

        sample_data = torch.normal(mean=data, std=gaussian_std).view(-1, 10).to(device=device)

        # tensor binary
        vog_second, v2 = rbm_second(sample_data)
        omse_loss = mse_loss(vog_second, v2)

        second_train_op.zero_grad()
        omse_loss.backward()
        second_train_op.step()
        
for _, (data) in enumerate(v2): 
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)

        sample_data = torch.normal(mean=data, std=gaussian_std).view(-1, 10).to(device=device)

        # tensor binary
        vog_second, v3 = rbm_third(sample_data)
        omse_loss = mse_loss(vog_second, v3)

        second_train_op.zero_grad()
        omse_loss.backward()
        second_train_op.step()

print("GB-DBN Training loss: {0}\tEstimate time : {1}\tAcc : {2}" .format(omse_loss, time.time() - start, acc * 100))

# %%
svm_v = torch.tensor(v3.clone().detach(), device=torch.device('cpu'))
print(svm_v)

# %%
X = torch.FloatTensor(svm_v)
Y = torch.FloatTensor(svm_v)
N = len(Y)

model = SVM(lr=LEARNING_RATE, n_x=10)
optimizer = optim.Adagrad(model.parameters(), lr=LEARNING_RATE)

correct = 0.
cnt_tot = 0

x = torch.tensor(X)
y = torch.tensor(Y)

# Forward
output = model(x)

# Backward
optimizer.zero_grad()
optimizer.step()

# %%
print(output)
