# %% [markdown]
# # Init set up

# %%
from ignite.contrib.metrics.regression import *
from ignite.contrib.metrics import *
from ignite.handlers import *
from ignite.metrics import *
from ignite.engine import *
from ignite.utils import *

from torch.utils.data import DataLoader
from torch.autograd import Variable
import torch.nn.functional as F
import data.read_samples as rs
import torch.optim as optim
import torch.utils.data
import torch.nn as nn

from collections import OrderedDict
import pandas as pd
import numpy as np
import datetime
import torch
import time
import os
import gc

print(datetime.datetime.now(), "model.py code start")

TRAIN_CSV_PATH = "./data/mitbih_train.csv"
TEST_CSV_PATH = "./data/mitbih_test.csv"

BATCH_SIZE = 187
EPOCH = 200
LEARNING_RATE = 0.2
ANNEALING_RATE = 0.999
HIDDEN_UNITS = [180, 200, 250, 80, 100, 120]
K_FOLD = 1
# Out:
# [INFO] Pre-processing for make clean
# 2022-05-19 13:26:59.207940 model.py code start

# %%
device = torch.device('cuda')
print(torch.cuda.get_device_name(device))
os.environ['KMP_DUPLICATE_LIB_OK']='True'
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
# Out:
# NVIDIA GeForce RTX 3080 Laptop GPU

# %%
class RBM(nn.Module): 
    with torch.cuda.device(0):
        def __init__(self, n_vis, n_hid, k, batch):
            super(RBM, self).__init__()
            self.W      = nn.Parameter(torch.randn(1, batch, device=device) * 1e-2)
            self.n_vis  = n_vis
            self.n_hid  = n_hid
            self.k      = k
            self.batch  = batch
            self.v_bias = nn.Parameter(torch.zeros(n_vis, 1, device=device))
            self.h_bias = nn.Parameter(torch.zeros(n_hid, 1, device=device))
        
        def sample_from_p(self, p):
            return F.relu(
                torch.sign(
                    p - Variable(torch.randn(p.size(), device=device))
                )
            ).to(device=device)

        ''' ISSUE PART '''
        def v_to_h(self, v):
            w = (self.W.clone())

            p_h = F.sigmoid(
                F.linear(v, w)
            ).to(device=device)

            sample_h = self.sample_from_p(p_h)
            return p_h, sample_h

        def h_to_v(self, h):
            w = self.W.t().clone()

            p_v = F.sigmoid(
                F.linear(h, w)
            ).to(device=device)

            sample_v = self.sample_from_p(p_v)
            return p_v, sample_v
        
        def forward(self, v):
            pre_h1, h1 = self.v_to_h(v)
            h_ = h1

            for _ in range(self.k):
                pre_v_, v_ = self.h_to_v(h_)
                pre_h_, h_ = self.v_to_h(v_)
            return v, v_
        
        def get_weight(self):
            return self.W

# %%
class SVM(nn.Module):
    def __init__(self, lr, n_x):
        super(SVM, self).__init__()
        self.lr = lr
        self.fully = nn.Linear(n_x, 1)
    
    def forward(self, x):
        fwd = self.fully(x)
        return fwd

# %%
def eval_step(engine, batch):
    return batch

default_model = nn.Sequential(OrderedDict([
    ('base', nn.Linear(4, 2)),
    ('fc', nn.Linear(2, 1))
]))

default_evaluator = Engine(eval_step)

def get_acc(y_true, y_pred):
    metric = Accuracy()
    metric.attach(default_evaluator, "accuracy")
    state = default_evaluator.run([[y_pred, y_true]])
    return state.metrics["accuracy"]

# %% [markdown]
# # Pre-processing

# %%
print("[MODL] Model main code is starting....")
print("[INFO] Read train data, cross-vaildation data and test data from median filtering code")

train_df = pd.read_csv(TRAIN_CSV_PATH, header=None).sample(frac=1)
test_df = pd.read_csv(TEST_CSV_PATH, header=None)

Y = np.array(train_df[187].values).astype(np.int8)
X = np.array(train_df[list(range(187))].values)[..., np.newaxis]

Y_test = np.array(test_df[187].values).astype(np.int8)
X_test = np.array(test_df[list(range(187))].values)[..., np.newaxis]

print(len(X), len(Y), len(X_test), len(Y_test))
print(type(X), type(Y), type(X_test), type(Y_test))
# Out:
# [MODL] Model main code is starting....
# [INFO] Read train data, cross-vaildation data and test data from median filtering code
# 87554 87554 21892 21892
# <class 'numpy.ndarray'> <class 'numpy.ndarray'> <class 'numpy.ndarray'> <class 'numpy.ndarray'>

# %%
train_dataset = []
cross_dataset = []
test_dataset = []

train_dataloader = DataLoader(X,
                              batch_size=BATCH_SIZE,
                              num_workers=0,
                              shuffle=True)

test_dataloader = DataLoader(Y,
                             batch_size=BATCH_SIZE,
                             num_workers=0,
                             shuffle=True)

# %% [markdown]
# ## Setting Models

# %%
bbrbm_first = RBM(n_vis=187, n_hid=HIDDEN_UNITS[0], k=K_FOLD, batch=BATCH_SIZE).to(device=device)
bbrbm_second = RBM(n_vis=187, n_hid=HIDDEN_UNITS[1], k=K_FOLD, batch=BATCH_SIZE).to(device=device)
bbrbm_third = RBM(n_vis=187, n_hid=HIDDEN_UNITS[2], k=K_FOLD, batch=BATCH_SIZE).to(device=device)

gbrbm_first = RBM(n_vis=187, n_hid=HIDDEN_UNITS[3], k=K_FOLD, batch=BATCH_SIZE).to(device=device)
gbrbm_second = RBM(n_vis=187, n_hid=HIDDEN_UNITS[4], k=K_FOLD, batch=BATCH_SIZE).to(device=device)
gbrbm_third = RBM(n_vis=187, n_hid=HIDDEN_UNITS[5], k=K_FOLD, batch=BATCH_SIZE).to(device=device)

first_train_op = optim.Adagrad(bbrbm_first.parameters(), LEARNING_RATE)
second_train_op = optim.Adagrad(bbrbm_second.parameters(), LEARNING_RATE)
third_train_op = optim.Adagrad(bbrbm_third.parameters(), LEARNING_RATE)

gb_first_train_op = optim.Adagrad(gbrbm_first.parameters(), LEARNING_RATE)
gb_second_train_op = optim.Adagrad(gbrbm_second.parameters(), LEARNING_RATE)
gb_third_train_op = optim.Adagrad(gbrbm_third.parameters(), LEARNING_RATE)

omse_loss = list()
output_gb = list()
best_acc = float()
mse_loss = nn.MSELoss()

gaussian_std = torch.arange(1, 0, -0.00537, device=device)
print(gaussian_std.size())

svm_X = torch.FloatTensor(output_gb)
svm_Y = torch.FloatTensor(Y)
N = len(svm_Y)

svm_model = SVM(lr=LEARNING_RATE, n_x=2577)
svm_optimizer = optim.Adagrad(svm_model.parameters(), lr=LEARNING_RATE)
# Out:
# torch.Size([187])

# %%
# # load_model = RBM(VISIBLE_UNITS[2], VISIBLE_UNITS[2], K_FOLD, BATCH_SIZE)
# # load_model.load_state_dict(torch.load("./saveMode_through_99_epoch_90.0_acc_GBDBN.pth"))

# LOAD_PATH = "./saveMode_through_99_epoch_90.0_acc_GBDBN.pth"

# load_model = RBM(VISIBLE_UNITS[2], HIDDEN_UNITS[2], K_FOLD, 10)
# load_model.load_state_dict((torch.load(LOAD_PATH)))
# load_model.to(device=device)

# for i, (data) in enumerate(test_dataloader):
#         if(data.size()[0] == 4):
#             break
#         data = Variable(
#                 torch.tensor(data, dtype=torch.float32)
#         ).uniform_(0, 1)
        
#         sample_data = torch.bernoulli(data).view(-1, 10).to(device=device)

#         # tensor binary
#         vog_first, v1 = load_model(sample_data)
#         omse_loss = mse_loss(vog_first, v1)

#         first_train_op.zero_grad()
#         first_train_op.step()
#         omse_loss.backward()
# get_acc(vog_first, v1)

# %% [markdown]
# # GB-DBN Train Code

# %%
'''BBRBM Train Part'''

loss_ = []
output_bb = []
print("RBM START!")

for epoch in range(EPOCH):
    tmp_acc = float()
    run_acc = float()
    start = time.time()
    '''First bbrbm'''
    for i, (data) in enumerate(train_dataloader):
        data = Variable(torch.tensor(data, dtype=torch.float32))
        if(data.size()[0] == 4):
            break
        
        sample_data = torch.bernoulli(data).view(-1, BATCH_SIZE).to(device=device)
        fs_data = sample_data
        
        # tensor binary
        fvog_first, v1 = bbrbm_first(sample_data)
        omse_loss = mse_loss(fvog_first, v1)
        
        first_train_op.zero_grad()
        first_train_op.step()
        omse_loss.backward()
    
    for _, (data) in enumerate(v1): 
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)

        sample_data = torch.bernoulli(data).view(-1, BATCH_SIZE).to(device=device)

        # tensor binary
        vog_second, v2 = bbrbm_second(sample_data)
        omse_loss = mse_loss(vog_second, v2)

        second_train_op.zero_grad()
        omse_loss.backward()
        second_train_op.step()
    
    for _, (data) in enumerate(v2):
        start = time.time()
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)

        sample_data = torch.bernoulli(data).view(-1, BATCH_SIZE).to(device=device)

        vog_third, v3 = bbrbm_third(sample_data)
        omse_loss = mse_loss(vog_third, v3)
        
        third_train_op.zero_grad()
        omse_loss.backward()
        third_train_op.step()

        run_acc += (sample_data == v3).sum().item()
    
    path = "./saveMode_through_BBRBM.pth"
    torch.save(bbrbm_second.state_dict(), path)
    output_bb.append(v3)

    '''
        GBRBM GBRBM GBRBM GBRBM GBRBM GBRBM GBRBM 
    '''

    for i, (data) in enumerate(output_bb):
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)
        
        sample_data = torch.normal(mean=data, std=gaussian_std).view(-1, BATCH_SIZE).to(device=device)

        # tensor binary
        vog_first, v1 = gbrbm_first(sample_data)
        omse_loss = mse_loss(vog_first, v1)

        gb_first_train_op.zero_grad()
        gb_first_train_op.step()
        omse_loss.backward()

    for _, (data) in enumerate(v1): 
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)

        sample_data = torch.normal(mean=data, std=gaussian_std).view(-1, BATCH_SIZE).to(device=device)

        # tensor binary
        vog_second, v2 = gbrbm_second(sample_data)
        omse_loss = mse_loss(vog_second, v2)

        gb_second_train_op.zero_grad()
        omse_loss.backward()
        gb_second_train_op.step()

    for _, (data) in enumerate(v2):
        start = time.time()
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)

        sample_data = torch.normal(mean=data, std=gaussian_std).view(-1, BATCH_SIZE).to(device=device)

        vog_third, v3_e = gbrbm_third(sample_data)
        omse_loss = mse_loss(vog_third, v3_e)
        
        gb_third_train_op.zero_grad()
        omse_loss.backward()
        gb_third_train_op.step()
    
    # perm = torch.randperm(N)
    # for i in range(0, N, BATCH_SIZE):
    #     correct = 0.

    #     x = svm_X[perm[i:i + BATCH_SIZE]]
    #     y = svm_Y[perm[i:i + BATCH_SIZE]]

    #     x = torch.tensor(x.clone().detach())
    #     y = torch.tensor(y.clone().detach())

    #     # Forward
    #     output = svm_model(x)
        
    #     # Backward
    #     svm_optimizer.zero_grad()        
    #     svm_optimizer.step()

    #     predicted = output.data >= 0
    #     correct += float(
    #         predicted.view(-1) == output.data
    #     )
    # torch.save(svm_model, "Train_svm_model.pth")
    
    acc_v = (vog_third >= 0).float()
    acc = get_acc(
        acc_v, v3_e
    ) * 100
    
    if acc > best_acc:
        best_acc = acc    
        path = "./say_cheese/ahh_saveMode_through_" + str(epoch) + "_" + str(acc) + "GBRBM.pth"
        torch.save(gbrbm_third.state_dict(), path)
    output_gb.append(v3_e)

    print("GB-DBN Training loss for {0}th epoch {1}\tEstimate time : {2}\tAcc : {3}\t\tBest Acc : {4}\t\tIgnite Acc: {5}" \
        .format(epoch + 1, omse_loss, time.time() - start, acc, best_acc, tmp_acc))
    gc.collect()
# Out:
# RBM START!
# C:\Users\HILAB_~1\AppData\Local\Temp/ipykernel_24656/2533437238.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data = Variable(torch.tensor(data, dtype=torch.float32))
# c:\Users\HILAB_Labtop_02\anaconda3\lib\site-packages\torch\nn\functional.py:1944: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# C:\Users\HILAB_~1\AppData\Local\Temp/ipykernel_24656/2533437238.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(data, dtype=torch.float32)
# C:\Users\HILAB_~1\AppData\Local\Temp/ipykernel_24656/2533437238.py:46: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(data, dtype=torch.float32)
# C:\Users\HILAB_~1\AppData\Local\Temp/ipykernel_24656/2533437238.py:70: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(data, dtype=torch.float32)
# C:\Users\HILAB_~1\AppData\Local\Temp/ipykernel_24656/2533437238.py:85: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(data, dtype=torch.float32)
# C:\Users\HILAB_~1\AppData\Local\Temp/ipykernel_24656/2533437238.py:101: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(data, dtype=torch.float32)
# GB-DBN Training loss for 1th epoch 0.6096152067184448	Estimate time : 0.005002498626708984	Acc : 63.63636363636363		Best Acc : 63.63636363636363		Ignite Acc: 0.0
# GB-DBN Training loss for 2th epoch 0.6211481094360352	Estimate time : 0.003999471664428711	Acc : 63.63636363636363		Best Acc : 63.63636363636363		Ignite Acc: 0.0
# GB-DBN Training loss for 3th epoch 0.8237432241439819	Estimate time : 0.00599980354309082	Acc : 48.663101604278076		Best Acc : 63.63636363636363		Ignite Acc: 0.0
# GB-DBN Training loss for 4th epoch 0.6942058801651001	Estimate time : 0.008999109268188477	Acc : 61.49732620320856		Best Acc : 63.63636363636363		Ignite Acc: 0.0
# GB-DBN Training loss for 5th epoch 0.7018454074859619	Estimate time : 0.008004188537597656	Acc : 57.21925133689839		Best Acc : 63.63636363636363		Ignite Acc: 0.0
# GB-DBN Training loss for 6th epoch 0.5711277723312378	Estimate time : 0.010996818542480469	Acc : 65.24064171122996		Best Acc : 65.24064171122996		Ignite Acc: 0.0
# GB-DBN Training loss for 7th epoch 0.6418677568435669	Estimate time : 0.008999824523925781	Acc : 64.70588235294117		Best Acc : 65.24064171122996		Ignite Acc: 0.0
# GB-DBN Training loss for 8th epoch 0.5288804769515991	Estimate time : 0.014000415802001953	Acc : 66.84491978609626		Best Acc : 66.84491978609626		Ignite Acc: 0.0
# GB-DBN Training loss for 9th epoch 0.5808593034744263	Estimate time : 0.012008905410766602	Acc : 61.49732620320856		Best Acc : 66.84491978609626		Ignite Acc: 0.0
# GB-DBN Training loss for 10th epoch 0.6932650804519653	Estimate time : 0.012000560760498047	Acc : 58.288770053475936		Best Acc : 66.84491978609626		Ignite Acc: 0.0
# GB-DBN Training loss for 11th epoch 0.6387105584144592	Estimate time : 0.012995243072509766	Acc : 63.63636363636363		Best Acc : 66.84491978609626		Ignite Acc: 0.0
# GB-DBN Training loss for 12th epoch 0.6176010370254517	Estimate time : 0.013709545135498047	Acc : 59.35828877005348		Best Acc : 66.84491978609626		Ignite Acc: 0.0
# GB-DBN Training loss for 13th epoch 0.5841249823570251	Estimate time : 0.01500248908996582	Acc : 63.101604278074866		Best Acc : 66.84491978609626		Ignite Acc: 0.0
# GB-DBN Training loss for 14th epoch 0.6767832040786743	Estimate time : 0.015996217727661133	Acc : 61.49732620320856		Best Acc : 66.84491978609626		Ignite Acc: 0.0
# GB-DBN Training loss for 15th epoch 0.6902753114700317	Estimate time : 0.017995834350585938	Acc : 66.31016042780749		Best Acc : 66.84491978609626		Ignite Acc: 0.0
# GB-DBN Training loss for 16th epoch 0.6380808353424072	Estimate time : 0.016000032424926758	Acc : 62.03208556149733		Best Acc : 66.84491978609626		Ignite Acc: 0.0
# GB-DBN Training loss for 17th epoch 0.743004322052002	Estimate time : 0.01900029182434082	Acc : 63.101604278074866		Best Acc : 66.84491978609626		Ignite Acc: 0.0
# GB-DBN Training loss for 18th epoch 0.7525680661201477	Estimate time : 0.016999006271362305	Acc : 56.14973262032086		Best Acc : 66.84491978609626		Ignite Acc: 0.0
# GB-DBN Training loss for 19th epoch 0.6993995904922485	Estimate time : 0.018991470336914062	Acc : 63.63636363636363		Best Acc : 66.84491978609626		Ignite Acc: 0.0
# GB-DBN Training loss for 20th epoch 0.7292386889457703	Estimate time : 0.01999950408935547	Acc : 58.288770053475936		Best Acc : 66.84491978609626		Ignite Acc: 0.0
# GB-DBN Training loss for 21th epoch 0.7318404316902161	Estimate time : 0.02200031280517578	Acc : 54.54545454545454		Best Acc : 66.84491978609626		Ignite Acc: 0.0
# GB-DBN Training loss for 22th epoch 0.6428256034851074	Estimate time : 0.022001028060913086	Acc : 65.24064171122996		Best Acc : 66.84491978609626		Ignite Acc: 0.0
# GB-DBN Training loss for 23th epoch 0.5878856182098389	Estimate time : 0.022998809814453125	Acc : 59.893048128342244		Best Acc : 66.84491978609626		Ignite Acc: 0.0
# GB-DBN Training loss for 24th epoch 0.7951939105987549	Estimate time : 0.0233612060546875	Acc : 52.406417112299465		Best Acc : 66.84491978609626		Ignite Acc: 0.0
# GB-DBN Training loss for 25th epoch 0.6602178812026978	Estimate time : 0.025999069213867188	Acc : 70.05347593582889		Best Acc : 70.05347593582889		Ignite Acc: 0.0
# GB-DBN Training loss for 26th epoch 0.6338009834289551	Estimate time : 0.024999380111694336	Acc : 57.75401069518716		Best Acc : 70.05347593582889		Ignite Acc: 0.0
# GB-DBN Training loss for 27th epoch 0.6584781408309937	Estimate time : 0.025999784469604492	Acc : 64.70588235294117		Best Acc : 70.05347593582889		Ignite Acc: 0.0
# GB-DBN Training loss for 28th epoch 0.538357675075531	Estimate time : 0.027008056640625	Acc : 68.44919786096256		Best Acc : 70.05347593582889		Ignite Acc: 0.0
# GB-DBN Training loss for 29th epoch 0.6908604502677917	Estimate time : 0.027999401092529297	Acc : 64.70588235294117		Best Acc : 70.05347593582889		Ignite Acc: 0.0
# GB-DBN Training loss for 30th epoch 0.6650468707084656	Estimate time : 0.027999162673950195	Acc : 66.31016042780749		Best Acc : 70.05347593582889		Ignite Acc: 0.0
# GB-DBN Training loss for 31th epoch 0.5794755220413208	Estimate time : 0.027999401092529297	Acc : 60.962566844919785		Best Acc : 70.05347593582889		Ignite Acc: 0.0
# GB-DBN Training loss for 32th epoch 0.7167388200759888	Estimate time : 0.02899909019470215	Acc : 65.24064171122996		Best Acc : 70.05347593582889		Ignite Acc: 0.0
# GB-DBN Training loss for 33th epoch 0.7800999879837036	Estimate time : 0.0299990177154541	Acc : 66.84491978609626		Best Acc : 70.05347593582889		Ignite Acc: 0.0
# GB-DBN Training loss for 34th epoch 0.6000171303749084	Estimate time : 0.03800082206726074	Acc : 65.77540106951871		Best Acc : 70.05347593582889		Ignite Acc: 0.0
# GB-DBN Training loss for 35th epoch 0.6604247093200684	Estimate time : 0.030999183654785156	Acc : 62.56684491978609		Best Acc : 70.05347593582889		Ignite Acc: 0.0
# GB-DBN Training loss for 36th epoch 0.7092494964599609	Estimate time : 0.034996986389160156	Acc : 63.101604278074866		Best Acc : 70.05347593582889		Ignite Acc: 0.0
# GB-DBN Training loss for 37th epoch 0.654366672039032	Estimate time : 0.030999422073364258	Acc : 60.962566844919785		Best Acc : 70.05347593582889		Ignite Acc: 0.0
# GB-DBN Training loss for 38th epoch 0.6187125444412231	Estimate time : 0.03299903869628906	Acc : 63.63636363636363		Best Acc : 70.05347593582889		Ignite Acc: 0.0
# GB-DBN Training loss for 39th epoch 0.6113457679748535	Estimate time : 0.03899979591369629	Acc : 61.49732620320856		Best Acc : 70.05347593582889		Ignite Acc: 0.0
# GB-DBN Training loss for 40th epoch 0.7194614410400391	Estimate time : 0.03401541709899902	Acc : 63.63636363636363		Best Acc : 70.05347593582889		Ignite Acc: 0.0
# GB-DBN Training loss for 41th epoch 0.7737187743186951	Estimate time : 0.03500008583068848	Acc : 63.101604278074866		Best Acc : 70.05347593582889		Ignite Acc: 0.0
# GB-DBN Training loss for 42th epoch 0.7294996976852417	Estimate time : 0.03800034523010254	Acc : 59.893048128342244		Best Acc : 70.05347593582889		Ignite Acc: 0.0
# GB-DBN Training loss for 43th epoch 0.6129454374313354	Estimate time : 0.03699994087219238	Acc : 64.70588235294117		Best Acc : 70.05347593582889		Ignite Acc: 0.0
# GB-DBN Training loss for 44th epoch 0.6331388354301453	Estimate time : 0.037999629974365234	Acc : 60.962566844919785		Best Acc : 70.05347593582889		Ignite Acc: 0.0
# GB-DBN Training loss for 45th epoch 0.6790605187416077	Estimate time : 0.03899812698364258	Acc : 64.70588235294117		Best Acc : 70.05347593582889		Ignite Acc: 0.0
# GB-DBN Training loss for 46th epoch 0.6328021287918091	Estimate time : 0.038999080657958984	Acc : 67.37967914438502		Best Acc : 70.05347593582889		Ignite Acc: 0.0
# GB-DBN Training loss for 47th epoch 0.6829008460044861	Estimate time : 0.040997982025146484	Acc : 60.962566844919785		Best Acc : 70.05347593582889		Ignite Acc: 0.0
# GB-DBN Training loss for 48th epoch 0.6212863326072693	Estimate time : 0.041013240814208984	Acc : 63.63636363636363		Best Acc : 70.05347593582889		Ignite Acc: 0.0
# GB-DBN Training loss for 49th epoch 0.5743263363838196	Estimate time : 0.042998552322387695	Acc : 63.63636363636363		Best Acc : 70.05347593582889		Ignite Acc: 0.0
# GB-DBN Training loss for 50th epoch 0.8386729955673218	Estimate time : 0.0429987907409668	Acc : 57.21925133689839		Best Acc : 70.05347593582889		Ignite Acc: 0.0
# GB-DBN Training loss for 51th epoch 0.7166656851768494	Estimate time : 0.04399538040161133	Acc : 58.82352941176471		Best Acc : 70.05347593582889		Ignite Acc: 0.0
# GB-DBN Training loss for 52th epoch 0.6966996192932129	Estimate time : 0.04500222206115723	Acc : 61.49732620320856		Best Acc : 70.05347593582889		Ignite Acc: 0.0
# GB-DBN Training loss for 53th epoch 0.6671080589294434	Estimate time : 0.04500007629394531	Acc : 63.101604278074866		Best Acc : 70.05347593582889		Ignite Acc: 0.0
# GB-DBN Training loss for 54th epoch 0.7193813920021057	Estimate time : 0.04659247398376465	Acc : 60.962566844919785		Best Acc : 70.05347593582889		Ignite Acc: 0.0
# GB-DBN Training loss for 55th epoch 0.6650664210319519	Estimate time : 0.046000003814697266	Acc : 60.962566844919785		Best Acc : 70.05347593582889		Ignite Acc: 0.0
# GB-DBN Training loss for 56th epoch 0.6693784594535828	Estimate time : 0.04698944091796875	Acc : 58.288770053475936		Best Acc : 70.05347593582889		Ignite Acc: 0.0
# GB-DBN Training loss for 57th epoch 0.6837413311004639	Estimate time : 0.04799771308898926	Acc : 55.080213903743314		Best Acc : 70.05347593582889		Ignite Acc: 0.0
# GB-DBN Training loss for 58th epoch 0.6693441867828369	Estimate time : 0.04899859428405762	Acc : 64.1711229946524		Best Acc : 70.05347593582889		Ignite Acc: 0.0
# GB-DBN Training loss for 59th epoch 0.6832590103149414	Estimate time : 0.04899883270263672	Acc : 60.42780748663101		Best Acc : 70.05347593582889		Ignite Acc: 0.0
# GB-DBN Training loss for 60th epoch 0.6576701998710632	Estimate time : 0.05000019073486328	Acc : 58.82352941176471		Best Acc : 70.05347593582889		Ignite Acc: 0.0
# GB-DBN Training loss for 61th epoch 0.7062486410140991	Estimate time : 0.05301165580749512	Acc : 64.70588235294117		Best Acc : 70.05347593582889		Ignite Acc: 0.0
# GB-DBN Training loss for 62th epoch 0.5286853313446045	Estimate time : 0.05099940299987793	Acc : 63.63636363636363		Best Acc : 70.05347593582889		Ignite Acc: 0.0
# GB-DBN Training loss for 63th epoch 0.6310178637504578	Estimate time : 0.05500984191894531	Acc : 62.03208556149733		Best Acc : 70.05347593582889		Ignite Acc: 0.0
# GB-DBN Training loss for 64th epoch 0.7211536169052124	Estimate time : 0.053000450134277344	Acc : 56.68449197860963		Best Acc : 70.05347593582889		Ignite Acc: 0.0
# GB-DBN Training loss for 65th epoch 0.6678261160850525	Estimate time : 0.058998823165893555	Acc : 60.962566844919785		Best Acc : 70.05347593582889		Ignite Acc: 0.0
# GB-DBN Training loss for 66th epoch 0.677631139755249	Estimate time : 0.05499863624572754	Acc : 68.98395721925134		Best Acc : 70.05347593582889		Ignite Acc: 0.0
# GB-DBN Training loss for 67th epoch 0.7661263346672058	Estimate time : 0.053999900817871094	Acc : 63.101604278074866		Best Acc : 70.05347593582889		Ignite Acc: 0.0
# GB-DBN Training loss for 68th epoch 0.5843346118927002	Estimate time : 0.057003021240234375	Acc : 72.19251336898395		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 69th epoch 0.6013123393058777	Estimate time : 0.05399966239929199	Acc : 60.42780748663101		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 70th epoch 0.7986717820167542	Estimate time : 0.0559999942779541	Acc : 51.87165775401069		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 71th epoch 0.7637647390365601	Estimate time : 0.056999921798706055	Acc : 65.24064171122996		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 72th epoch 0.498520165681839	Estimate time : 0.0559999942779541	Acc : 67.9144385026738		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 73th epoch 0.6466876268386841	Estimate time : 0.05899953842163086	Acc : 62.56684491978609		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 74th epoch 0.7011428475379944	Estimate time : 0.05936241149902344	Acc : 63.63636363636363		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 75th epoch 0.6742955446243286	Estimate time : 0.060999155044555664	Acc : 60.962566844919785		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 76th epoch 0.7922159433364868	Estimate time : 0.06099557876586914	Acc : 63.101604278074866		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 77th epoch 0.6710644364356995	Estimate time : 0.05900001525878906	Acc : 60.962566844919785		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 78th epoch 0.686944842338562	Estimate time : 0.062000274658203125	Acc : 59.893048128342244		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 79th epoch 0.7494552731513977	Estimate time : 0.0640559196472168	Acc : 62.56684491978609		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 80th epoch 0.6962524652481079	Estimate time : 0.06554770469665527	Acc : 66.84491978609626		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 81th epoch 0.6348820924758911	Estimate time : 0.06399846076965332	Acc : 65.24064171122996		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 82th epoch 0.6098601222038269	Estimate time : 0.06399869918823242	Acc : 60.962566844919785		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 83th epoch 0.694297194480896	Estimate time : 0.06499934196472168	Acc : 59.893048128342244		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 84th epoch 0.8112279772758484	Estimate time : 0.06700682640075684	Acc : 58.288770053475936		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 85th epoch 0.6109691858291626	Estimate time : 0.06900405883789062	Acc : 63.101604278074866		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 86th epoch 0.5909582376480103	Estimate time : 0.06700015068054199	Acc : 65.77540106951871		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 87th epoch 0.6678463220596313	Estimate time : 0.0709996223449707	Acc : 67.9144385026738		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 88th epoch 0.664537250995636	Estimate time : 0.0690000057220459	Acc : 59.35828877005348		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 89th epoch 0.6406674981117249	Estimate time : 0.0689992904663086	Acc : 60.42780748663101		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 90th epoch 0.6719824075698853	Estimate time : 0.06899881362915039	Acc : 57.75401069518716		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 91th epoch 0.6254123449325562	Estimate time : 0.0820009708404541	Acc : 62.03208556149733		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 92th epoch 0.6167927980422974	Estimate time : 0.07250261306762695	Acc : 61.49732620320856		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 93th epoch 0.6458816528320312	Estimate time : 0.07200002670288086	Acc : 63.63636363636363		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 94th epoch 0.7888252139091492	Estimate time : 0.07299590110778809	Acc : 59.35828877005348		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 95th epoch 0.5581726431846619	Estimate time : 0.07399749755859375	Acc : 66.84491978609626		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 96th epoch 0.6591318249702454	Estimate time : 0.07599949836730957	Acc : 64.1711229946524		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 97th epoch 0.6278030872344971	Estimate time : 0.07800030708312988	Acc : 65.77540106951871		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 98th epoch 0.6774415969848633	Estimate time : 0.07500362396240234	Acc : 59.893048128342244		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 99th epoch 0.5740569233894348	Estimate time : 0.07999563217163086	Acc : 66.31016042780749		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 100th epoch 0.6333932280540466	Estimate time : 0.07999157905578613	Acc : 69.5187165775401		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 101th epoch 0.7168750762939453	Estimate time : 0.076995849609375	Acc : 64.70588235294117		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 102th epoch 0.6507928967475891	Estimate time : 0.07899689674377441	Acc : 60.962566844919785		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 103th epoch 0.775863766670227	Estimate time : 0.08005619049072266	Acc : 63.101604278074866		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 104th epoch 0.5957497954368591	Estimate time : 0.08099818229675293	Acc : 66.84491978609626		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 105th epoch 0.7129492163658142	Estimate time : 0.07999634742736816	Acc : 68.98395721925134		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 106th epoch 0.6299288272857666	Estimate time : 0.08099746704101562	Acc : 64.70588235294117		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 107th epoch 0.6076971888542175	Estimate time : 0.08299541473388672	Acc : 57.75401069518716		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 108th epoch 0.6806513667106628	Estimate time : 0.0820000171661377	Acc : 56.68449197860963		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 109th epoch 0.5482571125030518	Estimate time : 0.0879964828491211	Acc : 62.56684491978609		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 110th epoch 0.6170759797096252	Estimate time : 0.08399581909179688	Acc : 66.31016042780749		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 111th epoch 0.741773784160614	Estimate time : 0.09005045890808105	Acc : 58.288770053475936		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 112th epoch 0.7278863787651062	Estimate time : 0.08500313758850098	Acc : 58.82352941176471		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 113th epoch 0.5500576496124268	Estimate time : 0.0879981517791748	Acc : 62.56684491978609		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 114th epoch 0.6479394435882568	Estimate time : 0.09000015258789062	Acc : 56.68449197860963		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 115th epoch 0.7883543968200684	Estimate time : 0.08800077438354492	Acc : 62.03208556149733		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 116th epoch 0.6369011402130127	Estimate time : 0.09100008010864258	Acc : 57.75401069518716		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 117th epoch 0.6664283871650696	Estimate time : 0.09026217460632324	Acc : 60.962566844919785		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 118th epoch 0.7010356187820435	Estimate time : 0.09200096130371094	Acc : 64.70588235294117		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 119th epoch 0.731156051158905	Estimate time : 0.0930018424987793	Acc : 59.35828877005348		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 120th epoch 0.6672565937042236	Estimate time : 0.09200024604797363	Acc : 63.63636363636363		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 121th epoch 0.7000985741615295	Estimate time : 0.09200024604797363	Acc : 63.63636363636363		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 122th epoch 0.5711688995361328	Estimate time : 0.09200406074523926	Acc : 67.9144385026738		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 123th epoch 0.7100071310997009	Estimate time : 0.09299969673156738	Acc : 60.962566844919785		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 124th epoch 0.7906349301338196	Estimate time : 0.09400296211242676	Acc : 52.94117647058824		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 125th epoch 0.7155453562736511	Estimate time : 0.09499931335449219	Acc : 57.75401069518716		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 126th epoch 0.6611757278442383	Estimate time : 0.09600424766540527	Acc : 56.14973262032086		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 127th epoch 0.7149046063423157	Estimate time : 0.0989990234375	Acc : 59.893048128342244		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 128th epoch 0.7250089049339294	Estimate time : 0.0969996452331543	Acc : 58.82352941176471		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 129th epoch 0.7123271226882935	Estimate time : 0.09899306297302246	Acc : 60.962566844919785		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 130th epoch 0.586687445640564	Estimate time : 0.09800100326538086	Acc : 59.893048128342244		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 131th epoch 0.7142530083656311	Estimate time : 0.09999561309814453	Acc : 62.03208556149733		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 132th epoch 0.5310649871826172	Estimate time : 0.10150814056396484	Acc : 67.9144385026738		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 133th epoch 0.7914866805076599	Estimate time : 0.10000014305114746	Acc : 63.101604278074866		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 134th epoch 0.6684761643409729	Estimate time : 0.10199975967407227	Acc : 66.31016042780749		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 135th epoch 0.46460750699043274	Estimate time : 0.10200047492980957	Acc : 65.77540106951871		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 136th epoch 0.674284040927887	Estimate time : 0.1049954891204834	Acc : 66.31016042780749		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 137th epoch 0.6037918329238892	Estimate time : 0.10356354713439941	Acc : 57.75401069518716		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 138th epoch 0.7004071474075317	Estimate time : 0.1050577163696289	Acc : 60.962566844919785		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 139th epoch 0.665776252746582	Estimate time : 0.10599684715270996	Acc : 64.1711229946524		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 140th epoch 0.7709082961082458	Estimate time : 0.10799694061279297	Acc : 58.82352941176471		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 141th epoch 0.5676924586296082	Estimate time : 0.10799813270568848	Acc : 58.82352941176471		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 142th epoch 0.6882539987564087	Estimate time : 0.10700011253356934	Acc : 72.19251336898395		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 143th epoch 0.6688529253005981	Estimate time : 0.10949945449829102	Acc : 60.42780748663101		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 144th epoch 0.6603800654411316	Estimate time : 0.10800004005432129	Acc : 60.962566844919785		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 145th epoch 0.6395374536514282	Estimate time : 0.10899949073791504	Acc : 60.42780748663101		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 146th epoch 0.7516107559204102	Estimate time : 0.11100363731384277	Acc : 58.82352941176471		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 147th epoch 0.5914091467857361	Estimate time : 0.1099996566772461	Acc : 63.63636363636363		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 148th epoch 0.7514253854751587	Estimate time : 0.11405086517333984	Acc : 64.1711229946524		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 149th epoch 0.6840799450874329	Estimate time : 0.11183714866638184	Acc : 65.77540106951871		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 150th epoch 0.590241551399231	Estimate time : 0.11599612236022949	Acc : 64.1711229946524		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 151th epoch 0.5403435230255127	Estimate time : 0.11399531364440918	Acc : 60.962566844919785		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 152th epoch 0.6487510800361633	Estimate time : 0.11562061309814453	Acc : 56.14973262032086		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 153th epoch 0.7577531337738037	Estimate time : 0.12000417709350586	Acc : 62.56684491978609		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 154th epoch 0.7699029445648193	Estimate time : 0.11499905586242676	Acc : 56.68449197860963		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 155th epoch 0.6354122757911682	Estimate time : 0.12164807319641113	Acc : 62.56684491978609		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 156th epoch 0.5859304666519165	Estimate time : 0.11800217628479004	Acc : 65.77540106951871		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 157th epoch 0.6612015962600708	Estimate time : 0.11751317977905273	Acc : 66.84491978609626		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 158th epoch 0.6659256219863892	Estimate time : 0.11655116081237793	Acc : 67.37967914438502		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 159th epoch 0.7398751974105835	Estimate time : 0.12500452995300293	Acc : 60.962566844919785		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 160th epoch 0.6757932305335999	Estimate time : 0.12199974060058594	Acc : 62.03208556149733		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 161th epoch 0.6423674821853638	Estimate time : 0.12059378623962402	Acc : 55.61497326203209		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 162th epoch 0.7085338234901428	Estimate time : 0.12100338935852051	Acc : 64.1711229946524		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 163th epoch 0.6708143353462219	Estimate time : 0.12200069427490234	Acc : 63.63636363636363		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 164th epoch 0.595389723777771	Estimate time : 0.12261509895324707	Acc : 63.101604278074866		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 165th epoch 0.7067050337791443	Estimate time : 0.1249997615814209	Acc : 57.21925133689839		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 166th epoch 0.7417090535163879	Estimate time : 0.1249992847442627	Acc : 56.14973262032086		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 167th epoch 0.5876582264900208	Estimate time : 0.12700414657592773	Acc : 60.42780748663101		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 168th epoch 0.6127870082855225	Estimate time : 0.1249992847442627	Acc : 66.31016042780749		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 169th epoch 0.6063860654830933	Estimate time : 0.12800359725952148	Acc : 65.24064171122996		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 170th epoch 0.7503484487533569	Estimate time : 0.12999582290649414	Acc : 59.893048128342244		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 171th epoch 0.6787688136100769	Estimate time : 0.1289997100830078	Acc : 63.101604278074866		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 172th epoch 0.7143785953521729	Estimate time : 0.1300067901611328	Acc : 57.75401069518716		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 173th epoch 0.6911041140556335	Estimate time : 0.14200472831726074	Acc : 66.31016042780749		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 174th epoch 0.7975151538848877	Estimate time : 0.13034605979919434	Acc : 59.893048128342244		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 175th epoch 0.7665279507637024	Estimate time : 0.13200020790100098	Acc : 59.35828877005348		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 176th epoch 0.5077294707298279	Estimate time : 0.14899873733520508	Acc : 67.9144385026738		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 177th epoch 0.6200454831123352	Estimate time : 0.13300180435180664	Acc : 68.44919786096256		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 178th epoch 0.6613799929618835	Estimate time : 0.1320021152496338	Acc : 64.70588235294117		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 179th epoch 0.5814750790596008	Estimate time : 0.13500308990478516	Acc : 63.63636363636363		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 180th epoch 0.6261699795722961	Estimate time : 0.13499975204467773	Acc : 67.37967914438502		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 181th epoch 0.639072060585022	Estimate time : 0.13600873947143555	Acc : 66.31016042780749		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 182th epoch 0.6935603618621826	Estimate time : 0.13499951362609863	Acc : 61.49732620320856		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 183th epoch 0.6531656384468079	Estimate time : 0.13900351524353027	Acc : 61.49732620320856		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 184th epoch 0.6677455306053162	Estimate time : 0.1359999179840088	Acc : 64.70588235294117		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 185th epoch 0.663836658000946	Estimate time : 0.13863420486450195	Acc : 68.98395721925134		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 186th epoch 0.6795578002929688	Estimate time : 0.14600396156311035	Acc : 57.75401069518716		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 187th epoch 0.6406832933425903	Estimate time : 0.14000535011291504	Acc : 62.03208556149733		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 188th epoch 0.7404189705848694	Estimate time : 0.14001774787902832	Acc : 57.75401069518716		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 189th epoch 0.7802338600158691	Estimate time : 0.14099931716918945	Acc : 60.962566844919785		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 190th epoch 0.7666767835617065	Estimate time : 0.1549992561340332	Acc : 56.14973262032086		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 191th epoch 0.7464212775230408	Estimate time : 0.1419992446899414	Acc : 60.42780748663101		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 192th epoch 0.8462199568748474	Estimate time : 0.14200043678283691	Acc : 52.406417112299465		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 193th epoch 0.6650248169898987	Estimate time : 0.1439962387084961	Acc : 66.31016042780749		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 194th epoch 0.759787917137146	Estimate time : 0.15199565887451172	Acc : 64.70588235294117		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 195th epoch 0.7016811966896057	Estimate time : 0.14699959754943848	Acc : 56.68449197860963		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 196th epoch 0.588716447353363	Estimate time : 0.1470038890838623	Acc : 63.63636363636363		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 197th epoch 0.6719576716423035	Estimate time : 0.14800333976745605	Acc : 62.56684491978609		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 198th epoch 0.5754265189170837	Estimate time : 0.14801025390625	Acc : 62.03208556149733		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 199th epoch 0.62344890832901	Estimate time : 0.14800357818603516	Acc : 63.63636363636363		Best Acc : 72.19251336898395		Ignite Acc: 0.0
# GB-DBN Training loss for 200th epoch 0.6355456113815308	Estimate time : 0.1486361026763916	Acc : 65.24064171122996		Best Acc : 72.19251336898395		Ignite Acc: 0.0

# %%
print("Last Accuracy : ", acc, "%")
# Out:
# Last Accuracy :  65.24064171122996 %

# %% [markdown]
# # 수업 듣는 중입니다다다마ㅏㄴ...........

# %%
# load_model = RBM(VISIBLE_UNITS[2], VISIBLE_UNITS[2], K_FOLD, BATCH_SIZE)
# load_model.load_state_dict(torch.load("./saveMode_through_99_epoch_90.0_acc_GBDBN.pth"))

LOAD_PATH = "./say_cheese/ahh_saveMode_through_1219_74.8663101604278GBRBM.pth"

load_model = RBM(n_vis=187, n_hid=120, k=K_FOLD, batch=BATCH_SIZE)
load_model.load_state_dict((torch.load(LOAD_PATH)))
load_model.to(device=device)

print(len(test_dataloader))

for i, (data) in enumerate(test_dataloader):
        if i == 468:
                break
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)
        
        sample_data = torch.bernoulli(data).to(device=device)

        # tensor binary
        vog_first, v1 = load_model(sample_data)
        omse_loss = mse_loss(vog_first, v1)

        first_train_op.zero_grad()
        first_train_op.step()
        omse_loss.backward()
get_acc(vog_first, v1)
# Out:
# 469
# C:\Users\HILAB_~1\AppData\Local\Temp/ipykernel_24656/3039969846.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(data, dtype=torch.float32)
# c:\Users\HILAB_Labtop_02\anaconda3\lib\site-packages\torch\nn\functional.py:1944: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# 0.45454545454545453

# %%
output_gb_cp = list()
cpu = torch.device('cpu')

# %% [markdown]
# # Test Code

# %%
run_acc = float()
best_acc = float()
print("Test Code GB-DBN Start")
for i, (data) in enumerate(test_dataloader):
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)
        
        sample_data = torch.bernoulli(data).view(-1, 10).to(device=device)

        # tensor binary
        vog_first, v1 = rbm_first(sample_data)
        omse_loss = mse_loss(vog_first, v1)

        first_train_op.zero_grad()
        first_train_op.step()
        omse_loss.backward()

for i, (data) in enumerate(v1):
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)
        
        sample_data = torch.bernoulli(data).view(-1, 10).to(device=device)

        # tensor binary
        vog_second, v2 = rbm_first(sample_data)
        omse_loss = mse_loss(vog_second, v2)

        second_train_op.zero_grad()
        second_train_op.step()
        omse_loss.backward()

for i, (data) in enumerate(v2):
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)
        
        sample_data = torch.bernoulli(data).view(-1, 10).to(device=device)

        # tensor binary
        vog_second, v3 = rbm_first(sample_data)
        omse_loss = mse_loss(vog_second, v3)

        second_train_op.zero_grad()
        second_train_op.step()
        omse_loss.backward()
        run_acc += (sample_data == v3).sum().item()
 
for _, (data) in enumerate(v3): 
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)

        sample_data = torch.normal(mean=data, std=gaussian_std).view(-1, 10).to(device=device)

        # tensor binary
        vog_second, v1 = rbm_first(sample_data)
        omse_loss = mse_loss(vog_second, v1)

        second_train_op.zero_grad()
        omse_loss.backward()
        second_train_op.step()

for _, (data) in enumerate(v1): 
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)

        sample_data = torch.normal(mean=data, std=gaussian_std).view(-1, 10).to(device=device)

        # tensor binary
        vog_second, v2 = rbm_second(sample_data)
        omse_loss = mse_loss(vog_second, v2)

        second_train_op.zero_grad()
        omse_loss.backward()
        second_train_op.step()
        
for _, (data) in enumerate(v2): 
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)

        sample_data = torch.normal(mean=data, std=gaussian_std).view(-1, 10).to(device=device)

        # tensor binary
        vog_second, v3 = rbm_third(sample_data)
        omse_loss = mse_loss(vog_second, v3)

        second_train_op.zero_grad()
        omse_loss.backward()
        second_train_op.step()

print("GB-DBN Training loss: {0}\tEstimate time : {1}\tAcc : {2}" .format(omse_loss, time.time() - start, acc * 100))

# %%
svm_v = torch.tensor(v3.clone().detach(), device=torch.device('cpu'))
print(svm_v)

# %%
X = torch.FloatTensor(svm_v)
Y = torch.FloatTensor(svm_v)
N = len(Y)

model = SVM(lr=LEARNING_RATE, n_x=10)
optimizer = optim.Adagrad(model.parameters(), lr=LEARNING_RATE)

correct = 0.
cnt_tot = 0

x = torch.tensor(X)
y = torch.tensor(Y)

# Forward
output = model(x)

# Backward
optimizer.zero_grad()
optimizer.step()

# %%
print(output)
