# %% [markdown]
# # Init set up

# %%
from ignite.contrib.metrics.regression import *
from ignite.contrib.metrics import *
from ignite.handlers import *
from ignite.metrics import *
from ignite.engine import *
from ignite.utils import *

from torch.utils.data import DataLoader
from torch.autograd import Variable
import torch.nn.functional as F
import data.read_samples as rs
import torch.optim as optim
import torch.utils.data
import torch.nn as nn

from collections import OrderedDict
import pandas as pd
import numpy as np
import datetime
import torch
import time
import os
import gc

print(datetime.datetime.now(), "model.py code start")

TRAIN_CSV_PATH = "./data/mitbih_train.csv"
TEST_CSV_PATH = "./data/mitbih_test.csv"

BATCH_SIZE = 10
EPOCH = 100
LEARNING_RATE = 0.2
ANNEALING_RATE = 0.999
VISIBLE_UNITS = [180, 200, 250]
HIDDEN_UNITS = [80, 100, 120]
K_FOLD = 1
# Out:
# [INFO] Pre-processing for make clean
# 2022-05-18 20:23:14.289784 model.py code start

# %%
device = torch.device('cuda')
print(torch.cuda.get_device_name(device))
os.environ['KMP_DUPLICATE_LIB_OK']='True'
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
# Out:
# NVIDIA GeForce RTX 3080 Laptop GPU

# %%
class RBM(nn.Module): 
    with torch.cuda.device(0):
        def __init__(self, n_vis, n_hid, k, batch):
            super(RBM, self).__init__()
            self.W      = nn.Parameter(torch.randn(1, batch, device=device) * 1e-2)
            self.n_vis  = n_vis
            self.n_hid  = n_hid
            self.k      = k
            self.batch  = batch
            self.v_bias = nn.Parameter(torch.zeros(n_vis, device=device))
            self.h_bias = nn.Parameter(torch.zeros(n_hid, device=device))
        
        def sample_from_p(self, p):
            return F.relu(
                torch.sign(
                    p - Variable(torch.randn(p.size(), device=device))
                )
            ).to(device=device)

        ''' ISSUE PART '''
        def v_to_h(self, v):
            w = (self.W.clone())

            p_h = F.sigmoid(
                F.linear(v, w)
            ).to(device=device)

            sample_h = self.sample_from_p(p_h)
            return p_h, sample_h

        def h_to_v(self, h):
            w = self.W.t().clone()

            p_v = F.sigmoid(
                F.linear(h, w)
            ).to(device=device)

            sample_v = self.sample_from_p(p_v)
            return p_v, sample_v
        
        def forward(self, v):
            pre_h1, h1 = self.v_to_h(v)
            h_ = h1

            for _ in range(self.k):
                pre_v_, v_ = self.h_to_v(h_)
                pre_h_, h_ = self.v_to_h(v_)
            return v, v_
        
        def get_weight(self):
            return self.W

# %%
class SVM(nn.Module):
    def __init__(self, lr, n_x):
        super(SVM, self).__init__()
        self.lr = lr
        self.fully = nn.Linear(n_x, 1)
    
    def forward(self, x):
        fwd = self.fully(x)
        return fwd

# %%
def eval_step(engine, batch):
    return batch

default_model = nn.Sequential(OrderedDict([
    ('base', nn.Linear(4, 2)),
    ('fc', nn.Linear(2, 1))
]))

default_evaluator = Engine(eval_step)

def get_acc(y_true, y_pred):
    metric = Accuracy()
    metric.attach(default_evaluator, "accuracy")
    state = default_evaluator.run([[y_pred, y_true]])
    return state.metrics["accuracy"]

# %% [markdown]
# # Pre-processing

# %%
print("[MODL] Model main code is starting....")
print("[INFO] Read train data, cross-vaildation data and test data from median filtering code")

train_df = pd.read_csv(TRAIN_CSV_PATH, header=None).sample(frac=1)
test_df = pd.read_csv(TEST_CSV_PATH, header=None)

Y = np.array(train_df[187].values).astype(np.int8)
X = np.array(train_df[list(range(187))].values)[..., np.newaxis]

Y_test = np.array(test_df[187].values).astype(np.int8)
X_test = np.array(test_df[list(range(187))].values)[..., np.newaxis]

print(len(X), len(Y), len(X_test), len(Y_test))
print(type(X), type(Y), type(X_test), type(Y_test))
# Out:
# [MODL] Model main code is starting....
# [INFO] Read train data, cross-vaildation data and test data from median filtering code
# 87554 87554 21892 21892
# <class 'numpy.ndarray'> <class 'numpy.ndarray'> <class 'numpy.ndarray'> <class 'numpy.ndarray'>

# %%
train_dataloader = DataLoader(X,
                              batch_size=BATCH_SIZE,
                              num_workers=0,
                              shuffle=True)

test_dataloader = DataLoader(Y,
                             batch_size=BATCH_SIZE,
                             num_workers=0,
                             shuffle=True)

# %% [markdown]
# ## Setting Models

# %%
rbm_first = RBM(n_vis=VISIBLE_UNITS[0], n_hid=HIDDEN_UNITS[0], k=K_FOLD, batch=BATCH_SIZE).to(device=device)
rbm_second = RBM(n_vis=VISIBLE_UNITS[1], n_hid=HIDDEN_UNITS[1], k=K_FOLD, batch=BATCH_SIZE).to(device=device)
rbm_third = RBM(n_vis=VISIBLE_UNITS[2], n_hid=HIDDEN_UNITS[2], k=K_FOLD, batch=BATCH_SIZE).to(device=device)

first_train_op = optim.Adagrad(rbm_first.parameters(), LEARNING_RATE)
second_train_op = optim.Adagrad(rbm_second.parameters(), LEARNING_RATE)
third_train_op = optim.Adagrad(rbm_third.parameters(), LEARNING_RATE)

gb_first_train_op = optim.Adagrad(rbm_first.parameters(), LEARNING_RATE)
gb_second_train_op = optim.Adagrad(rbm_second.parameters(), LEARNING_RATE)
gb_third_train_op = optim.Adagrad(rbm_third.parameters(), LEARNING_RATE)

omse_loss = list()
output_bb = list()
output_gb = list()
best_acc = 0.
mse_loss = nn.MSELoss()

gaussian_std = torch.arange(1, 0, -0.1, device=device)

svm_model = SVM(lr=LEARNING_RATE, n_x=10)
svm_optimizer = optim.Adagrad(svm_model.parameters(), lr=LEARNING_RATE)

# %% [markdown]
# # GB-DBN Train Code

# %%
'''BBRBM Train Part'''

loss_ = []
print("RBM START!")

for epoch in range(EPOCH):
    tmp_acc = float()
    run_acc = float()
    start = time.time()
    '''First bbrbm'''
    for i, (data) in enumerate(train_dataloader):
        data = Variable(torch.tensor(data, dtype=torch.float32))
        if(data.size()[0] == 4):
            break
        
        sample_data = torch.bernoulli(data).view(-1, 10).to(device=device)
        fs_data = sample_data
        # tensor binary
        fvog_first, v1 = rbm_first(sample_data)
        omse_loss = mse_loss(fvog_first, v1)
        
        first_train_op.zero_grad()
        first_train_op.step()
        omse_loss.backward()
    
    for _, (data) in enumerate(v1): 
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)

        sample_data = torch.bernoulli(data).view(-1, 10).to(device=device)

        # tensor binary
        vog_second, v2 = rbm_second(sample_data)
        omse_loss = mse_loss(vog_second, v2)

        second_train_op.zero_grad()
        omse_loss.backward()
        second_train_op.step()
    
    for _, (data) in enumerate(v2):
        start = time.time()
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)

        sample_data = torch.bernoulli(data).view(-1, 10).to(device=device)

        vog_third, v3 = rbm_third(sample_data)
        omse_loss = mse_loss(vog_third, v3)
        
        third_train_op.zero_grad()
        omse_loss.backward()
        third_train_op.step()

        run_acc += (sample_data == v3).sum().item()
    output_bb.append(v3)

    '''
GBRBM GBRBM GBRBM GBRBM GBRBM GBRBM GBRBM 
    '''

    for i, (data) in enumerate(output_bb):
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)
        
        sample_data = torch.normal(mean=data, std=gaussian_std).view(-1, 10).to(device=device)

        # tensor binary
        vog_first, v1 = rbm_first(sample_data)
        omse_loss = mse_loss(vog_first, v1)

        first_train_op.zero_grad()
        first_train_op.step()
        omse_loss.backward()

    for _, (data) in enumerate(v1): 
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)

        sample_data = torch.normal(mean=data, std=gaussian_std).view(-1, 10).to(device=device)

        # tensor binary
        vog_second, v2 = rbm_second(sample_data)
        omse_loss = mse_loss(vog_second, v2)

        second_train_op.zero_grad()
        omse_loss.backward()
        second_train_op.step()

    for _, (data) in enumerate(v2):
        start = time.time()
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)

        sample_data = torch.normal(mean=data, std=gaussian_std).view(-1, 10).to(device=device)

        vog_third, v3_e = rbm_third(sample_data)
        omse_loss = mse_loss(vog_third, v3_e)
        
        third_train_op.zero_grad()
        omse_loss.backward()
        third_train_op.step()

        # output_gb.append(torch.flatten(v3_e).tolist())
        run_acc += (torch.bernoulli(data).view(-1, 10).to(device=device) == v3_e).sum().item()  
    
    acc_v = (vog_third >= 0).float()
    acc = get_acc(
        acc_v, v3_e
    ) * 100
    
    if acc >= best_acc:
        best_acc = acc    
        path = "./BATCH_10_saveMode_through_" + str(epoch) + "_epoch_" + str(best_acc) + "_acc_GBDBN.pth"
        torch.save(rbm_third.state_dict(), path)

    print("GB-DBN Training loss for {0}th epoch {1}\tEstimate time : {2}\tAcc : {3}\tBest Acc : {4}\t\tIgnite Acc: {5}" \
        .format(epoch + 1, omse_loss, time.time() - start, acc, best_acc, tmp_acc))
    gc.collect()
# Out:
# RBM START!
# C:\Users\HILAB_~1\AppData\Local\Temp/ipykernel_27732/2795252899.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data = Variable(torch.tensor(data, dtype=torch.float32))
# c:\Users\HILAB_Labtop_02\anaconda3\lib\site-packages\torch\nn\functional.py:1944: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# C:\Users\HILAB_~1\AppData\Local\Temp/ipykernel_27732/2795252899.py:28: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(data, dtype=torch.float32)
# C:\Users\HILAB_~1\AppData\Local\Temp/ipykernel_27732/2795252899.py:44: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(data, dtype=torch.float32)
# C:\Users\HILAB_~1\AppData\Local\Temp/ipykernel_27732/2795252899.py:65: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(data, dtype=torch.float32)
# C:\Users\HILAB_~1\AppData\Local\Temp/ipykernel_27732/2795252899.py:80: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(data, dtype=torch.float32)
# C:\Users\HILAB_~1\AppData\Local\Temp/ipykernel_27732/2795252899.py:96: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(data, dtype=torch.float32)
# GB-DBN Training loss for 1th epoch 0.5767474174499512	Estimate time : 0.011999845504760742	Acc : 60.0	Best Acc : 60.0		Ignite Acc: 0.0
# GB-DBN Training loss for 2th epoch 0.49167728424072266	Estimate time : 0.02500009536743164	Acc : 40.0	Best Acc : 60.0		Ignite Acc: 0.0
# GB-DBN Training loss for 3th epoch 0.7050332427024841	Estimate time : 0.021000146865844727	Acc : 50.0	Best Acc : 60.0		Ignite Acc: 0.0
# GB-DBN Training loss for 4th epoch 1.1408703327178955	Estimate time : 0.3510003089904785	Acc : 40.0	Best Acc : 60.0		Ignite Acc: 0.0
# GB-DBN Training loss for 5th epoch 1.1489231586456299	Estimate time : 0.026000261306762695	Acc : 60.0	Best Acc : 60.0		Ignite Acc: 0.0
# GB-DBN Training loss for 6th epoch 0.8722740411758423	Estimate time : 0.015623331069946289	Acc : 40.0	Best Acc : 60.0		Ignite Acc: 0.0
# GB-DBN Training loss for 7th epoch 0.3960364758968353	Estimate time : 0.031000614166259766	Acc : 60.0	Best Acc : 60.0		Ignite Acc: 0.0
# GB-DBN Training loss for 8th epoch 1.477250337600708	Estimate time : 0.021991491317749023	Acc : 70.0	Best Acc : 70.0		Ignite Acc: 0.0
# GB-DBN Training loss for 9th epoch 0.5149543285369873	Estimate time : 0.03242349624633789	Acc : 70.0	Best Acc : 70.0		Ignite Acc: 0.0
# GB-DBN Training loss for 10th epoch 1.0421687364578247	Estimate time : 0.03913760185241699	Acc : 40.0	Best Acc : 70.0		Ignite Acc: 0.0
# GB-DBN Training loss for 11th epoch 1.0509699583053589	Estimate time : 0.037000179290771484	Acc : 60.0	Best Acc : 70.0		Ignite Acc: 0.0
# GB-DBN Training loss for 12th epoch 0.308436781167984	Estimate time : 0.03600025177001953	Acc : 60.0	Best Acc : 70.0		Ignite Acc: 0.0
# GB-DBN Training loss for 13th epoch 1.211032748222351	Estimate time : 0.023998737335205078	Acc : 40.0	Best Acc : 70.0		Ignite Acc: 0.0
# GB-DBN Training loss for 14th epoch 1.0089346170425415	Estimate time : 0.029000043869018555	Acc : 50.0	Best Acc : 70.0		Ignite Acc: 0.0
# GB-DBN Training loss for 15th epoch 0.5504099726676941	Estimate time : 0.03415107727050781	Acc : 90.0	Best Acc : 90.0		Ignite Acc: 0.0
# GB-DBN Training loss for 16th epoch 0.38577553629875183	Estimate time : 0.03600668907165527	Acc : 100.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 17th epoch 1.0062686204910278	Estimate time : 0.034941673278808594	Acc : 50.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 18th epoch 1.0624351501464844	Estimate time : 0.03699994087219238	Acc : 50.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 19th epoch 0.7169339060783386	Estimate time : 0.05200028419494629	Acc : 50.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 20th epoch 0.376747190952301	Estimate time : 0.05099892616271973	Acc : 70.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 21th epoch 0.33098500967025757	Estimate time : 0.07063078880310059	Acc : 80.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 22th epoch 0.2654434144496918	Estimate time : 0.07224559783935547	Acc : 80.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 23th epoch 0.68853759765625	Estimate time : 0.060999393463134766	Acc : 70.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 24th epoch 0.3790948688983917	Estimate time : 0.05500078201293945	Acc : 80.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 25th epoch 0.5400875210762024	Estimate time : 0.06500029563903809	Acc : 60.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 26th epoch 0.4477010667324066	Estimate time : 0.08200263977050781	Acc : 70.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 27th epoch 0.7559241056442261	Estimate time : 0.03999900817871094	Acc : 80.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 28th epoch 0.8338781595230103	Estimate time : 0.054000139236450195	Acc : 60.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 29th epoch 0.7173909544944763	Estimate time : 0.0449976921081543	Acc : 50.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 30th epoch 0.375028133392334	Estimate time : 0.06301045417785645	Acc : 100.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 31th epoch 1.1559953689575195	Estimate time : 0.049610137939453125	Acc : 40.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 32th epoch 0.8465362787246704	Estimate time : 0.05500030517578125	Acc : 40.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 33th epoch 1.5386297702789307	Estimate time : 0.05400538444519043	Acc : 60.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 34th epoch 0.24903173744678497	Estimate time : 0.05799984931945801	Acc : 30.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 35th epoch 1.9707828760147095	Estimate time : 0.051001548767089844	Acc : 30.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 36th epoch 0.7767715454101562	Estimate time : 0.06360244750976562	Acc : 70.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 37th epoch 0.28190717101097107	Estimate time : 0.054000139236450195	Acc : 70.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 38th epoch 1.579703688621521	Estimate time : 0.06599760055541992	Acc : 60.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 39th epoch 0.5613295435905457	Estimate time : 0.05999493598937988	Acc : 60.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 40th epoch 0.31761565804481506	Estimate time : 0.059999942779541016	Acc : 70.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 41th epoch 0.34262552857398987	Estimate time : 0.07299947738647461	Acc : 70.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 42th epoch 0.858613133430481	Estimate time : 0.07399964332580566	Acc : 60.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 43th epoch 1.2217029333114624	Estimate time : 0.07200050354003906	Acc : 50.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 44th epoch 0.5866727828979492	Estimate time : 0.07500076293945312	Acc : 60.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 45th epoch 0.40158209204673767	Estimate time : 0.08251452445983887	Acc : 80.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 46th epoch 0.7346763014793396	Estimate time : 0.07800006866455078	Acc : 70.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 47th epoch 0.35361799597740173	Estimate time : 0.0780026912689209	Acc : 80.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 48th epoch 0.8561615347862244	Estimate time : 0.0710000991821289	Acc : 60.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 49th epoch 0.7352994680404663	Estimate time : 0.07900238037109375	Acc : 40.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 50th epoch 0.6173141598701477	Estimate time : 0.08699965476989746	Acc : 30.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 51th epoch 0.6419273614883423	Estimate time : 0.0839998722076416	Acc : 50.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 52th epoch 0.200923353433609	Estimate time : 0.07599735260009766	Acc : 80.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 53th epoch 0.5702220797538757	Estimate time : 0.09200000762939453	Acc : 60.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 54th epoch 0.5850791335105896	Estimate time : 0.07999992370605469	Acc : 70.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 55th epoch 0.39719006419181824	Estimate time : 0.09999918937683105	Acc : 70.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 56th epoch 0.8146418929100037	Estimate time : 0.10100245475769043	Acc : 60.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 57th epoch 0.6756520867347717	Estimate time : 0.08699965476989746	Acc : 70.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 58th epoch 1.1817272901535034	Estimate time : 0.09800004959106445	Acc : 50.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 59th epoch 0.8042430877685547	Estimate time : 0.09999990463256836	Acc : 60.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 60th epoch 0.749668538570404	Estimate time : 0.10499978065490723	Acc : 50.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 61th epoch 0.4784523546695709	Estimate time : 0.1029975414276123	Acc : 80.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 62th epoch 0.53101646900177	Estimate time : 0.10361838340759277	Acc : 80.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 63th epoch 0.7955229878425598	Estimate time : 0.1040043830871582	Acc : 50.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 64th epoch 0.8959412574768066	Estimate time : 0.10800457000732422	Acc : 70.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 65th epoch 0.3022782504558563	Estimate time : 0.1100003719329834	Acc : 70.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 66th epoch 0.5336633324623108	Estimate time : 0.11799979209899902	Acc : 70.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 67th epoch 1.0682730674743652	Estimate time : 0.10499763488769531	Acc : 50.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 68th epoch 1.1258858442306519	Estimate time : 0.11500000953674316	Acc : 80.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 69th epoch 0.7610862255096436	Estimate time : 0.12400269508361816	Acc : 60.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 70th epoch 0.9285580515861511	Estimate time : 0.11300015449523926	Acc : 60.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 71th epoch 0.9266332983970642	Estimate time : 0.12199759483337402	Acc : 60.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 72th epoch 0.6104595065116882	Estimate time : 0.10800290107727051	Acc : 40.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 73th epoch 0.6373891234397888	Estimate time : 0.11500024795532227	Acc : 80.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 74th epoch 0.6877378821372986	Estimate time : 0.12299966812133789	Acc : 70.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 75th epoch 0.9675637483596802	Estimate time : 0.12200021743774414	Acc : 30.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 76th epoch 0.32255157828330994	Estimate time : 0.12900352478027344	Acc : 80.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 77th epoch 0.8153983950614929	Estimate time : 0.12400031089782715	Acc : 80.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 78th epoch 1.4152531623840332	Estimate time : 0.12799978256225586	Acc : 40.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 79th epoch 0.49239587783813477	Estimate time : 0.1255970001220703	Acc : 70.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 80th epoch 1.365310788154602	Estimate time : 0.13899970054626465	Acc : 40.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 81th epoch 0.6041760444641113	Estimate time : 0.1340043544769287	Acc : 80.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 82th epoch 0.9427301287651062	Estimate time : 0.13800048828125	Acc : 60.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 83th epoch 0.9868583679199219	Estimate time : 0.1259937286376953	Acc : 30.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 84th epoch 0.9635009765625	Estimate time : 0.1419999599456787	Acc : 60.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 85th epoch 1.170435905456543	Estimate time : 0.1400012969970703	Acc : 50.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 86th epoch 0.782433271408081	Estimate time : 0.13199996948242188	Acc : 60.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 87th epoch 0.9407640695571899	Estimate time : 0.13199996948242188	Acc : 60.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 88th epoch 0.20140305161476135	Estimate time : 0.1360001564025879	Acc : 40.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 89th epoch 0.9051260948181152	Estimate time : 0.14560818672180176	Acc : 60.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 90th epoch 0.4126695692539215	Estimate time : 0.1530003547668457	Acc : 60.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 91th epoch 0.4995376765727997	Estimate time : 0.15399932861328125	Acc : 30.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 92th epoch 0.8763516545295715	Estimate time : 0.16099977493286133	Acc : 60.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 93th epoch 0.4865865409374237	Estimate time : 0.15799832344055176	Acc : 70.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 94th epoch 0.8981820940971375	Estimate time : 0.1549999713897705	Acc : 50.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 95th epoch 0.6048168540000916	Estimate time : 0.16564106941223145	Acc : 80.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 96th epoch 0.8009375929832458	Estimate time : 0.16000008583068848	Acc : 50.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 97th epoch 0.9491325616836548	Estimate time : 0.16060352325439453	Acc : 60.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 98th epoch 0.32901477813720703	Estimate time : 0.16282415390014648	Acc : 90.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 99th epoch 0.5353388786315918	Estimate time : 0.16306376457214355	Acc : 60.0	Best Acc : 100.0		Ignite Acc: 0.0
# GB-DBN Training loss for 100th epoch 0.607602059841156	Estimate time : 0.1640000343322754	Acc : 70.0	Best Acc : 100.0		Ignite Acc: 0.0

# %%
# load_model = RBM(VISIBLE_UNITS[2], VISIBLE_UNITS[2], K_FOLD, BATCH_SIZE)
# load_model.load_state_dict(torch.load("./saveMode_through_99_epoch_90.0_acc_GBDBN.pth"))

LOAD_PATH = "./saveMode_through_99_epoch_90.0_acc_GBDBN.pth"

load_model = RBM(VISIBLE_UNITS[2], HIDDEN_UNITS[2], K_FOLD, BATCH_SIZE)
load_model.load_state_dict((torch.load(LOAD_PATH)))
load_model.to(device=device)

for i, (data) in enumerate(test_dataloader):
        if(data.size()[0] == 4):
            break
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)
        
        sample_data = torch.bernoulli(data).view(-1, 10).to(device=device)

        # tensor binary
        vog_first, v1 = load_model(sample_data)
        omse_loss = mse_loss(vog_first, v1)

        first_train_op.zero_grad()
        first_train_op.step()
        omse_loss.backward()
get_acc(vog_first, v1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\HILAB_~1\AppData\Local\Temp/ipykernel_27732/3447300694.py in <module>
#       5
#       6 load_model = RBM(VISIBLE_UNITS[2], HIDDEN_UNITS[2], K_FOLD, BATCH_SIZE)
# ----> 7 load_model.load_state_dict((torch.load(LOAD_PATH)))
#       8 load_model.to(device=device)
#       9
#
# c:\Users\HILAB_Labtop_02\anaconda3\lib\site-packages\torch\serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     697         pickle_load_args['encoding'] = 'utf-8'
#     698
# --> 699     with _open_file_like(f, 'rb') as opened_file:
#     700         if _is_zipfile(opened_file):
#     701             # The zipfile reader is going to advance the current file position.
#
# c:\Users\HILAB_Labtop_02\anaconda3\lib\site-packages\torch\serialization.py in _open_file_like(name_or_buffer, mode)
#     229 def _open_file_like(name_or_buffer, mode):
#     230     if _is_path(name_or_buffer):
# --> 231         return _open_file(name_or_buffer, mode)
#     232     else:
#     233         if 'w' in mode:
#
# c:\Users\HILAB_Labtop_02\anaconda3\lib\site-packages\torch\serialization.py in __init__(self, name, mode)
#     210 class _open_file(_opener):
#     211     def __init__(self, name, mode):
# --> 212         super(_open_file, self).__init__(open(name, mode))
#     213
#     214     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: './saveMode_through_99_epoch_90.0_acc_GBDBN.pth'

# %%
print("Last Accuracy : ", acc, "%")

# %%
cpu = torch.device('cpu')

# %%
db3_label_chan = list()
v_model_acc = list()

for i in range(len(Y)):
    temp_list = []
    temp_bool = []
    for j in range(2577):
        try:
            temp_str = db3_label[i][j]
        except IndexError:
            temp_str = ""

        if temp_str == "V":
            temp_list.append(0)
            temp_bool.append(True)

        else:
            temp_list.append(1)
            temp_bool.append(False)

    db3_label_chan.append(temp_list)
    v_model_acc.append(temp_bool)

# %%
correct = 0.
cnt_tot = 0

for epoch in range(EPOCH):
    perm = torch.randperm(N)
    for  i in range(0, N, BATCH_SIZE):
        x = svm_X[perm[i:i + BATCH_SIZE]]
        y = svm_Y[perm[i:i + BATCH_SIZE]]

        x = torch.tensor(x.clone().detach())
        y = torch.tensor(y.clone().detach())

        # Forward
        output = model(x)
        
        # Backward
        optimizer.zero_grad()        
        optimizer.step()

        predicted = output.data >= 0
        correct += float(
            predicted.view(-1) == output.data
        )

        cnt_tot += 1
    print("Epoch: {}\tLoss: {}\tTotal Cnt: {}".format(epoch, correct, cnt_tot))
    torch.save(model, "Train_svm_model.pth")

# %% [markdown]
# # Test Code

# %%
run_acc = float()
best_acc = float()
print("Test Code GB-DBN Start")
for i, (data) in enumerate(test_dataloader):
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)
        
        sample_data = torch.bernoulli(data).view(-1, 10).to(device=device)

        # tensor binary
        vog_first, v1 = rbm_first(sample_data)
        omse_loss = mse_loss(vog_first, v1)

        first_train_op.zero_grad()
        first_train_op.step()
        omse_loss.backward()

for i, (data) in enumerate(v1):
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)
        
        sample_data = torch.bernoulli(data).view(-1, 10).to(device=device)

        # tensor binary
        vog_second, v2 = rbm_first(sample_data)
        omse_loss = mse_loss(vog_second, v2)

        second_train_op.zero_grad()
        second_train_op.step()
        omse_loss.backward()

for i, (data) in enumerate(v2):
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)
        
        sample_data = torch.bernoulli(data).view(-1, 10).to(device=device)

        # tensor binary
        vog_second, v3 = rbm_first(sample_data)
        omse_loss = mse_loss(vog_second, v3)

        second_train_op.zero_grad()
        second_train_op.step()
        omse_loss.backward()
        run_acc += (sample_data == v3).sum().item()
 
for _, (data) in enumerate(v3): 
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)

        sample_data = torch.normal(mean=data, std=gaussian_std).view(-1, 10).to(device=device)

        # tensor binary
        vog_second, v1 = rbm_first(sample_data)
        omse_loss = mse_loss(vog_second, v1)

        second_train_op.zero_grad()
        omse_loss.backward()
        second_train_op.step()

for _, (data) in enumerate(v1): 
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)

        sample_data = torch.normal(mean=data, std=gaussian_std).view(-1, 10).to(device=device)

        # tensor binary
        vog_second, v2 = rbm_second(sample_data)
        omse_loss = mse_loss(vog_second, v2)

        second_train_op.zero_grad()
        omse_loss.backward()
        second_train_op.step()
        
for _, (data) in enumerate(v2): 
        data = Variable(
                torch.tensor(data, dtype=torch.float32)
        ).uniform_(0, 1)

        sample_data = torch.normal(mean=data, std=gaussian_std).view(-1, 10).to(device=device)

        # tensor binary
        vog_second, v3 = rbm_third(sample_data)
        omse_loss = mse_loss(vog_second, v3)

        second_train_op.zero_grad()
        omse_loss.backward()
        second_train_op.step()

print("GB-DBN Training loss: {0}\tEstimate time : {1}\tAcc : {2}" .format(omse_loss, time.time() - start, acc * 100))

# %%
svm_v = torch.tensor(v3.clone().detach(), device=torch.device('cpu'))
print(svm_v)

# %%
X = torch.FloatTensor(svm_v)
Y = torch.FloatTensor(svm_v)
N = len(Y)

model = SVM(lr=LEARNING_RATE, n_x=10)
optimizer = optim.Adagrad(model.parameters(), lr=LEARNING_RATE)

correct = 0.
cnt_tot = 0

x = torch.tensor(X)
y = torch.tensor(Y)

# Forward
output = model(x)

# Backward
optimizer.zero_grad()
optimizer.step()

# %%
print(output)
